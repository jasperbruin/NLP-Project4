# %% [markdown]
# ## Importing Libraries

# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"
import torch
import logging
logging.basicConfig(level=logging.ERROR)
# If there's a GPU available...
if torch.cuda.is_available():

    # Tell PyTorch to use the GPU.
    device = torch.device("cuda")

    print('There are %d GPU(s) available.' % torch.cuda.device_count())

    print('We will use the GPU:', torch.cuda.get_device_name(0))

# If not...
else:
    print('No GPU available, using the CPU instead.')
    device = torch.device("cpu")
# Out:
# There are 1 GPU(s) available.
# We will use the GPU: Tesla T4

# %%
from transformers import AutoTokenizer,AutoModel

# Load the BERT tokenizer.
print('Loading tokenizer...')
tokenizer = AutoTokenizer.from_pretrained('sileod/deberta-v3-base-tasksource-nli', do_lower_case=True)
# Out:
# Loading tokenizer...
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/1.28k [00:00<?, ?B/s]
# spm.model:   0%|          | 0.00/2.46M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/8.66M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/23.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/286 [00:00<?, ?B/s]

# %%
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %%
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()

# %% [markdown]
# ## Setting up data

# %%
import json
with open("/content/drive/MyDrive/TUDelft/NLP Group Project/data/train_claims_quantemp.json") as f:
  train_data = json.load(f)
len(train_data)
# Out:
# 9935

# %%
import json
with open("/content/drive/MyDrive/TUDelft/NLP Group Project/data/val_claims_quantemp.json") as f:
  val_data = json.load(f)
len(val_data)
# Out:
# 3084

# %%
val_data[-1]
# Out:
# {'crawled_date': '2022-10-06T21:00:06',
#  'country_of_origin': 'usa',
#  'label': 'True',
#  'url': 'https://www.politifact.com/factchecks/2021/oct/28/randy-feenstra/biden-administration-predicted-liquid-fuel-cars-ou/',
#  'lang': 'en',
#  'claim': 'The Biden administration "published a study concluding 4 (of) 5 new cars on the road by 2050 will still require liquid fuels."',
#  'doc': 'President Joe Biden was in Michigan’s auto industry hub on Oct. 5 when he said, "the whole world knows that the future of the auto industry is electric." Rep. Randy Feenstra, R-Iowa, had a quick response, writing on Twitter: ".@POTUS no it’s not — in fact, your own administration published a study concluding 4/5 new cars on the road by 2050 will still require liquid fuels ... "It’s past time Biden lives up to his promise to expand clean-burning #biofuels. Don’t mess with the RFS!" Feenstra is correct about the share of cars in the United States projected to use liquid fuels. The U.S. Energy Information Administration’s 2021 Annual Energy Outlook report, which projects the nation’s environmental plans through 2050, says about 79% of new vehicle sales will be powered by liquid fuels — gasoline and blends that include up to 85% ethanol — in 2050. They accounted for 95% of sales in 2020, the report states. PolitiFact contacted Feenstra’s communications staff over 10 times for comment but did not receive a response. However, Feenstra’s tweet shared the link to his sourcing, and on page 15, the federal report notes that, while electric energy’s biggest demand growth area is transportation, the share will be small — less than 3%: "Current laws and regulations are not projected to induce much market growth, despite continuing improvements in electric vehicles (EVs) through evolutionary market developments. Both vehicle sales and utilization (miles driven) would need to increase substantially for EVs to raise electric power demand growth rates by more than a fraction of a percentage point per year." And, on the report’s page 26: "Because most light-duty vehicles have internal combustion engines, motor gasoline remains the major transportation fuel through 2050 as personal travel returns to pre-pandemic per-driver levels in the longer term." While 2050 is 29 years down the road, Biden did not state in Michigan a time limit on when he thinks electric power would come close to liquid fuels’ share of the automobile market. Nor did he state in detail what that future for electric power for automobiles would be. His administration’s Annual Energy Outlook reports that it is not predicting future energy use; rather it is a projection based on assumptions and methodologies that can be changed when subjected to changes in technology, demographics and resources. The report also notes that it is a response to the Department of Energy Organization Act of 1977. That law requires the U.S. Energy Information Administration to produce annual reports on trends and projections for energy use and supply, the report notes. But Feenstra was precise with his facts, and is not alone reminding Biden to support biofuels. Other Iowa congressional members, Republican and Democrat, have pushed for biofuels support, regardless of who is president. So has the biofuels industry. The reason? Iowa leads the nation when it comes to producing biofuels from farm crops. It has capacity to produce 4.6 billion gallons, double the 2.3 billion in the No. 2 state, Nebraska. While we focused this story on predicted biofuels use in vehicles, it’s worth noting that Biden promised support for biofuels in a Sept. 9, 2020, campaign statement that criticized a pre-election policy reversal by then-President Donald Trump on biofuels. Trump’s reversal led to his administration’s rejection of oil refinery industry requests to be exempt from requirements to blend certain amounts of ethanol and biodiesel in gasoline: "A Biden-Harris Administration will fight for family farmers and revitalize rural economies — from keeping our promises to farmers by ushering in a new era of biofuels, to investing in the broadband infrastructure and rural health care access that families and communities need," the Biden statement read. Trump reversed course again and approved on Jan. 19, 2021, just before leaving office, three biofuel waivers for refineries. Feenstra said the Biden Administration pre ...
#  'taxonomy_label': 'statistical',
#  'label_original': 'true'}

# %%
with open('/content/drive/MyDrive/TUDelft/NLP Group Project/data/test_claims_quantemp.json', 'r') as file:
    test_data = json.load(file)
len(test_data)
# Out:
# 2495

# %% [markdown]
# # BM25

# %% [markdown]
# ## BM25 Setup

# %%
pip install rank_bm25
# Out:
# Collecting rank_bm25
#   Downloading rank_bm25-0.2.2-py3-none-any.whl (8.6 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rank_bm25) (1.25.2)
# Installing collected packages: rank_bm25
# Successfully installed rank_bm25-0.2.2

# %%
import re
from rank_bm25 import BM25Okapi

# %%
with open("/content/drive/MyDrive/TUDelft/NLP Group Project/bm25/corpus_evidence_unified.json") as f:
  document_corpus = json.load(f)

# %%
def preprocess_text(text):
	text = text.lower()
	text = re.sub(r'\s\.\.\.', '', text)
	text = re.sub(r'\.', '', text)
	text = text.split(" ")
	return text

# %%
corpus = list(document_corpus.values())
tokenized_corpus = []
for doc in corpus:
	tokenized_corpus.append(preprocess_text(doc))

bm25 = BM25Okapi(tokenized_corpus)

# %%
# query = val_data[16]['claim']
# results = bm25.get_top_n(preprocess_text(query), corpus, n=5)

# print("Query\n",query)
# print("\nResults:")
# for result in results:
#   print(result)

# %%
def get_features_oracle(data):
  features = []
  evidences = []

  for index, fact in enumerate(data):
    claim = fact["claim"]


    feature = "[Claim]:"+claim+"[Evidences]:"+fact["doc"]
    features.append(feature)
  return features

# %%
import json
from tqdm import tqdm

def preprocess_text(text):
    text = text.lower()
    text = re.sub(r'\s\.\.\.', '', text)
    text = re.sub(r'\.', '', text)
    text = text.split(" ")
    return text

def process_claim(claim):
    """
    Processes a claim to generate a feature string by fetching top relevant evidences using the global BM25 object.
    """
    preprocessed_claim = preprocess_text(claim)
    results = bm25.get_top_n(preprocessed_claim, corpus, n=5)
    evidences = ' '.join(results)
    return "[Claim]:" + (' '.join(preprocessed_claim)) + "[Evidences]:" + evidences

def get_features(data, save_path, pick_up_from=None):
    """
    Processes a list of data to extract features using the global BM25 object.
    Each claim is processed sequentially.
    Progress is saved every 10 claims and can resume from a saved state using JSON format.
    """
    features = []
    start_index = 0

    # Check if we need to pick up from a previous state
    if pick_up_from:
        with open(pick_up_from, 'r') as file:
            features = json.load(file)
            start_index = len(features)  # Determine where to start processing
            print(f"Picking up from {start_index} claims")

    # Prepare to save progress every 10 claims
    def save_progress(features):
        with open(save_path, 'w') as file:
            json.dump(features, file, ensure_ascii=False, indent=2)

    # Process each claim sequentially
    for idx in tqdm(range(start_index, len(data)), desc="Processing Claims"):
        claim = data[idx]['claim']
        try:
            result = process_claim(claim)
            features.append(result)


            if (len(features) - start_index) % 10 == 0:
                save_progress(features)
        except Exception as e:
            print(f"Error processing claim at index {idx}: {str(e)}")

    # Save any remaining processed claims
    save_progress(features)

    return features

# Example usage
# get_features(data, 'output_path.json')

# %% [markdown]
# ## Run BM25

# %%
train_features = get_features(train_data,
                              save_path = '/content/drive/MyDrive/TUDelft/NLP Group Project/bm25/bm25_features_train_set.json',
                              pick_up_from='/content/drive/MyDrive/TUDelft/NLP Group Project/bm25/bm25_features_train_set.json')
len(train_features)
# Out:
# Picking up from 9935 claims
# Processing Claims: 0it [00:00, ?it/s]
# 9935

# %%
train_features[0]
# Out:
# '[Claim]:in her budget speech, nirmala sitharaman claimed that the government distributed 35,000 crore led bulbs in the country[Evidences]:conclusion: nirmala sitharaman didn\'t claim that govt distributed 35,000 crores led bulbs. from the video fo the speech it is clear that she said 35 crores. nirmala sitharaman didn\'t claim that govt distributed 35,000 crores led bulbs. from the video of the speech, it is clear that she said 35 crores, not 35000 crores. 7 feb 2017  "the government has distributed 21 crore led bulbs and due to this power bills have been reduced and rs 11,000 crore was saved," the prime ... 34.7 crore led lamps were distributed to replace icl. . (100w). additionally around ... as on date, 14.05 lakh led bulbs have been distributed across the state ...148 pagine the government has recovered non-performing assets (npas) worth rs 4 lakh crore over the past four years, finance minister nirmala sitharaman said on friday. in the past one year, npas worth rs 1 lakh crore has been recovered, she said while presenting the first full-fledged union budget of narendra modi 2.0 government in parliament. 2023-02-07  union budget 20232024: finance minister nirmala sitharaman increased the budget allocation for the msme sector and announced new ...'

# %%
test_features = get_features(test_data,
                              save_path = '/content/drive/MyDrive/TUDelft/NLP Group Project/bm25/bm25_features_test_set.json',
                              pick_up_from='/content/drive/MyDrive/TUDelft/NLP Group Project/bm25/bm25_features_test_set.json')
len(test_features)
# Out:
# Picking up from 2495 claims
# Processing Claims: 0it [00:00, ?it/s]
# 2495

# %%
test_features[0]
# Out:
# '[Claim]:"the non-partisan congressional budget office concluded obamacare will cost the us more than 800,000 jobs"[Evidences]:jun 14, 2011  ... congressional budget office testified before congress that implementation of obamacare would cost 800,000 jobs." bachmann made nearly the ... this non-partisan congressional budget office report confirms that obamacare will cost america 2 million jobs ... budget analysts said in the most detailed ... jun 13, 2013  the non-partisan congressional budget office estimates the pp aca will eliminate roughly 800,000 jobs. 7. the federal reserve recently ... the director of the congressional budget office testified last year that obamacare will destroy 800,000 jobs and this summer the u.s. chamber of commerce ... 2014-02-24  the non-partisan congressional budget office recently reported that obamacare will shrink the economy by the equivalent of 2.5 million full-time ...'

# %%
val_features = get_features(val_data,
                              save_path = '/content/drive/MyDrive/TUDelft/NLP Group Project/bm25/bm25_features_val_set.json',
                              pick_up_from='/content/drive/MyDrive/TUDelft/NLP Group Project/bm25/bm25_features_val_set.json')
len(val_features)
# Out:
# Picking up from 3084 claims
# Processing Claims: 0it [00:00, ?it/s]
# 3084

# %%
val_features[0]
# Out:
# '[Claim]:amit shah said narendra modi sleeps for 24 hours for the welfare of the poor[Evidences]:a businessman-turned-politician and senior bharatiya janata party (bjp) leader, amit shah became the union home minister in the second term of the narendra modi ... amit shah is the union home minister of the current government. a close associate of prime minister narendra modi, amit shah was the party president before ... 2014. in 2014, after shri narendra modi became the prime minister of india. mr. amit shah was appointed the president of "gujarat state cricket association". 2017-02-11  obama sleeps nearly five hours a night. narendra modi. pti. 2/2. narendra modi. prime minister narendra modi is said to work 20 hours a day. 8 dc. 2022  the bharatiya janata party set new records in the home state of pm narendra modi and home minister amit shah with a \'historic\' victory.'

# %% [markdown]
# ## Fix order mismacth of BM25 caused by parallization

# %%
pip install fuzzywuzzy
# Out:
# Collecting fuzzywuzzy
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Installing collected packages: fuzzywuzzy
# Successfully installed fuzzywuzzy-0.18.0

# %%
import json
import re
from fuzzywuzzy import process

def normalize_text(text):
    return ' '.join(re.sub(r'[^\w\s]', '', text.lower()).strip().split())

def get_initial_key(text, n=6):
    words = normalize_text(text).split()
    return ' '.join(words[:n])

# Load the data
with open("/content/drive/MyDrive/TUDelft/NLP Group Project/data/train_claims_quantemp.json") as f:
    train_data = json.load(f)

with open("/content/drive/MyDrive/TUDelft/NLP Group Project/bm25/bm25_features_train_set.json") as f:
    train_features = json.load(f)

# Create hash map for quick lookup
hash_map = {}
for idx, item in enumerate(train_data):
    key = get_initial_key(item['claim'])
    if key not in hash_map:
        hash_map[key] = []
    hash_map[key].append(idx)

# Prepare for ordered features and unmatched tracking
ordered_train_features = [None] * len(train_data)
unmatched_features = []

# Process features
for feature in tqdm(train_features):
    extracted_claim = normalize_text(feature.split("[Evidences]:")[0].replace("[Claim]:", ""))
    initial_key = get_initial_key(extracted_claim)

    if initial_key in hash_map and len(hash_map[initial_key]) == 1:
        # Direct match
        index = hash_map[initial_key][0]
        ordered_train_features[index] = feature
    else:
        # Fallback to fuzzy matching when multiple or no direct matches
        possible_matches = [train_data[i]['claim'] for i in hash_map.get(initial_key, [])]
        best_match, score = process.extractOne(extracted_claim, possible_matches)
        if score >= 85:  # Adjust threshold as needed
            index = train_data.index(next(item for item in train_data if item['claim'] == best_match))
            ordered_train_features[index] = feature
        else:
            unmatched_features.append(feature)

# Print results
matched = sum(1 for x in ordered_train_features if x is not None)
unmatched = len(unmatched_features)

print(f"\nMatched entries: {matched}, Unmatched entries: {unmatched}")


# Define the path where you want to save the results
output_file_path = "/content/drive/MyDrive/TUDelft/NLP Group Project/bm25/ordered_bm25_features_train_set.json"

# Save the ordered features to a file
with open(output_file_path, 'w') as f:
    json.dump(ordered_train_features, f, indent=4)

print(f"Ordered features saved successfully to {output_file_path}")
# Out:
# 100%|██████████| 9935/9935 [00:03<00:00, 2908.10it/s]
# Matched entries: 9830, Unmatched entries: 0

# %%
import json
import re
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

def preprocess_text(text):
    text = text.lower()
    text = re.sub(r'\s\.\.\.', '', text)
    text = re.sub(r'\.', '', text)
    text = text.split(" ")
    return text

# Load the JSON files
with open('/content/drive/MyDrive/TUDelft/NLP Group Project/data/train_claims_quantemp.json', 'r') as file:
    train_claims = json.load(file)

with open('/content/drive/MyDrive/TUDelft/NLP Group Project/bm25/bm25_features_train_set.json', 'r') as file:
    bm25_features = json.load(file)

# Create a dictionary for fast lookup of bm25 claims
bm25_dict = {}
for entry in bm25_features:
    claim = entry.split("[Claim]:")[1].split("[Evidences]")[0].strip()
    preprocessed_claim = " ".join(preprocess_text(claim))
    bm25_dict[preprocessed_claim] = entry

# Prepare the ordered bm25 features list
ordered_bm25_features = []
unmatched_claims = []

for claim in tqdm(train_claims):
    original_claim = claim["claim"]
    preprocessed_claim = " ".join(preprocess_text(original_claim))
    bm25_entry = bm25_dict.get(preprocessed_claim)
    if bm25_entry:
        ordered_bm25_features.append(bm25_entry)
    else:
        unmatched_claims.append((original_claim, preprocessed_claim))

# Handle unmatched claims using fuzzy matching
if unmatched_claims:
    bm25_claims = list(bm25_dict.keys())
    for original_claim, preprocessed_claim in tqdm(unmatched_claims):
        match, score = process.extractOne(preprocessed_claim, bm25_claims, scorer=fuzz.token_sort_ratio)
        if score > 80:  # Adjust the threshold as needed
            ordered_bm25_features.append(bm25_dict[match])
        else:
            print(f"Warning: No good match found for claim: {original_claim}")

# Save the ordered bm25 features to a new file
with open('/content/drive/MyDrive/TUDelft/NLP Group Project/bm25/ordered_bm25_features_train_set.json', 'w') as file:
    json.dump(ordered_bm25_features, file)

print("Ordered BM25 features file created successfully!")
# Out:
# 100%|██████████| 9935/9935 [00:00<00:00, 46919.53it/s]
#  42%|████▏     | 19/45 [02:14<03:10,  7.34s/it]
# Warning: No good match found for claim: In 2016, Speaker Paul Ryan said free lunches gave children a "full stomach" but left them with an "empty soul."
#  42%|████▏     | 19/45 [02:19<03:11,  7.36s/it]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/fuzzywuzzy/process.py in extractWithoutOrder(query, choices, processor, scorer, score_cutoff)
#     107         # See if choices is a dictionary-like object.
# --> 108         for key, choice in choices.items():
#     109             processed = pre_processor(processor(choice))
#
# AttributeError: 'list' object has no attribute 'items'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-18979f39c960> in <cell line: 41>()
#      42     bm25_claims = list(bm25_dict.keys())
#      43     for original_claim, preprocessed_claim in tqdm(unmatched_claims):
# ---> 44         match, score = process.extractOne(preprocessed_claim, bm25_claims, scorer=fuzz.token_sort_ratio)
#      45         if score > 80:  # Adjust the threshold as needed
#      46             ordered_bm25_features.append(bm25_dict[match])
#
# /usr/local/lib/python3.10/dist-packages/fuzzywuzzy/process.py in extractOne(query, choices, processor, scorer, score_cutoff)
#     218     best_list = extractWithoutOrder(query, choices, processor, scorer, score_cutoff)
#     219     try:
# --> 220         return max(best_list, key=lambda i: i[1])
#     221     except ValueError:
#     222         return None
#
# /usr/local/lib/python3.10/dist-packages/fuzzywuzzy/process.py in extractWithoutOrder(query, choices, processor, scorer, score_cutoff)
#     115         for choice in choices:
#     116             processed = pre_processor(processor(choice))
# --> 117             score = scorer(processed_query, processed)
#     118             if score >= score_cutoff:
#     119                 yield (choice, score)
#
# /usr/local/lib/python3.10/dist-packages/fuzzywuzzy/fuzz.py in token_sort_ratio(s1, s2, force_ascii, full_process)
#     103     but sorting the token before comparing.
#     104     """
# --> 105     return _token_sort(s1, s2, partial=False, force_ascii=force_ascii, full_process=full_process)
#     106
#     107
#
# /usr/local/lib/python3.10/dist-packages/fuzzywuzzy/utils.py in decorator(*args, **kwargs)
#      36         if args[0] is None or args[1] is None:
#      37             return 0
# ---> 38         return func(*args, **kwargs)
#      39     return decorator
#      40
#
# /usr/local/lib/python3.10/dist-packages/fuzzywuzzy/fuzz.py in _token_sort(s1, s2, partial, force_ascii, full_process)
#      96         return partial_ratio(sorted1, sorted2)
#      97     else:
# ---> 98         return ratio(sorted1, sorted2)
#      99
#     100
#
# /usr/local/lib/python3.10/dist-packages/fuzzywuzzy/utils.py in decorator(*args, **kwargs)
#      36         if args[0] is None or args[1] is None:
#      37             return 0
# ---> 38         return func(*args, **kwargs)
#      39     return decorator
#      40
#
# /usr/local/lib/python3.10/dist-packages/fuzzywuzzy/utils.py in decorator(*args, **kwargs)
#      27         if args[0] == args[1]:
#      28             return 100
# ---> 29         return func(*args, **kwargs)
#      30     return decorator
#      31
#
# /usr/local/lib/python3.10/dist-packages/fuzzywuzzy/utils.py in decorator(*args, **kwargs)
#      45         if len(args[0]) == 0 or len(args[1]) == 0:
#      46             return 0
# ---> 47         return func(*args, **kwargs)
#      48     return decorator
#      49
#
# /usr/local/lib/python3.10/dist-packages/fuzzywuzzy/fuzz.py in ratio(s1, s2)
#      26
#      27     m = SequenceMatcher(None, s1, s2)
# ---> 28     return utils.intr(100 * m.ratio())
#      29
#      30
#
# /usr/lib/python3.10/difflib.py in ratio(self)
#     617         """
#     618
# --> 619         matches = sum(triple[-1] for triple in self.get_matching_blocks())
#     620         return _calculate_ratio(matches, len(self.a) + len(self.b))
#     621
#
# /usr/lib/python3.10/difflib.py in get_matching_blocks(self)
#     452         while queue:
#     453             alo, ahi, blo, bhi = queue.pop()
# --> 454             i, j, k = x = self.find_longest_match(alo, ahi, blo, bhi)
#     455             # a[alo:i] vs b[blo:j] unknown
#     456             # a[i:i+k] same as b[j:j+k]
#
# /usr/lib/python3.10/difflib.py in find_longest_match(self, alo, ahi, blo, bhi)
#     384                     break
#     385                 k = newj2len[j] = j2lenget(j-1, 0) + 1
# --> 386                 if k > bestsize:
#     387                     besti, bestj, bestsize = i-k+1, j-k+1, k
#     388             j2len = newj2len
#
# KeyboardInterrupt:

# %%
import json
import re
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

def preprocess_text(text):
    text = text.lower()
    text = re.sub(r'\s\.\.\.', '', text)
    text = re.sub(r'\.', '', text)
    text = text.split(" ")
    return text

# Load the JSON files
with open('/content/drive/MyDrive/TUDelft/NLP Group Project/data/train_claims_quantemp.json', 'r') as file:
    train_claims = json.load(file)

with open('/content/drive/MyDrive/TUDelft/NLP Group Project/bm25/bm25_features_train_set.json', 'r') as file:
    bm25_features = json.load(file)

# Create a dictionary for fast lookup of bm25 claims
bm25_dict = {}
for entry in bm25_features:
    claim = entry.split("[Claim]:")[1].split("[Evidences]")[0].strip()
    preprocessed_claim = " ".join(preprocess_text(claim))
    bm25_dict[preprocessed_claim] = entry

# Prepare the ordered bm25 features list with placeholders
ordered_bm25_features = [None] * len(train_claims)
unmatched_claims = []

for i, claim in tqdm(enumerate(train_claims)):
    original_claim = claim["claim"]
    preprocessed_claim = " ".join(preprocess_text(original_claim))
    bm25_entry = bm25_dict.get(preprocessed_claim)
    if bm25_entry:
        ordered_bm25_features[i] = bm25_entry
    else:
        unmatched_claims.append((i, original_claim, preprocessed_claim))

# Handle unmatched claims using fuzzy matching
if unmatched_claims:
    bm25_claims = list(bm25_dict.keys())
    for index, original_claim, preprocessed_claim in tqdm(unmatched_claims):
        match, score = process.extractOne(preprocessed_claim, bm25_claims, scorer=fuzz.token_sort_ratio)
        if score > 80:  # Adjust the threshold as needed
            ordered_bm25_features[index] = bm25_dict[match]
            bm25_claims.remove(match)  # Remove the matched claim to avoid duplicates
        else:
            print(f"Warning: No good match found for claim: {original_claim}")

# Fill remaining None slots with unmatched bm25 features
remaining_bm25_entries = [entry for entry in bm25_features if entry not in ordered_bm25_features]
for i, entry in tqdm(enumerate(ordered_bm25_features)):
    if entry is None and remaining_bm25_entries:
        ordered_bm25_features[i] = remaining_bm25_entries.pop(0)

# Save the ordered bm25 features to a new file
with open('/content/drive/MyDrive/TUDelft/NLP Group Project/bm25/ordered_bm25_features_train_set.json', 'w') as file:
    json.dump(ordered_bm25_features, file)

print("Ordered BM25 features file created successfully!")
# Out:
# 9935it [00:00, 47154.96it/s]
#  42%|████▏     | 19/45 [02:17<03:06,  7.16s/it]
# Warning: No good match found for claim: In 2016, Speaker Paul Ryan said free lunches gave children a "full stomach" but left them with an "empty soul."
#  44%|████▍     | 20/45 [02:28<03:28,  8.34s/it]
# Warning: No good match found for claim: "We bring in enough tax revenue to service our debt, pay for Medicare and Medicaid and Social Security, and then still have about $300 (billion) or $400 billion left over."
#  78%|███████▊  | 35/45 [04:18<01:15,  7.52s/it]
# Warning: No good match found for claim: Finance experts estimate that paying in cash for the $2.5 billion in projects funded by the sales tax saved Gwinnett County more than $1 billion in interest payments.
#  98%|█████████▊| 44/45 [05:19<00:06,  6.62s/it]
# Warning: No good match found for claim: Rajasthan government made UP government pay 19 lakhs at midnight and then allows the buses to leave from Kota
# 100%|██████████| 45/45 [05:27<00:00,  7.28s/it]
# 9935it [00:00, 1397913.73it/s]
# Ordered BM25 features file created successfully!

# %%
import json
import random

# Load the JSON files
with open('/content/drive/MyDrive/TUDelft/NLP Group Project/data/train_claims_quantemp.json', 'r') as file:
    train_claims = json.load(file)

with open('/content/drive/MyDrive/TUDelft/NLP Group Project/bm25/ordered_bm25_features_train_set.json', 'r') as file:
    ordered_bm25_features = json.load(file)

# Function to extract claim from bm25 entry
def extract_claim(bm25_entry):
    return bm25_entry.split("[Claim]:")[1].split("[Evidences]")[0].strip()

# Indices to check: first few, last few, and 5 random
indices_to_check = list(range(5)) + list(range(len(train_claims) - 5, len(train_claims)))
indices_to_check += random.sample(range(5, len(train_claims) - 5), 5)

# Check and print claims
for idx in indices_to_check:
    original_claim = train_claims[idx]["claim"]
    bm25_entry = ordered_bm25_features[idx]
    bm25_claim = extract_claim(bm25_entry)

    print(f"Index: {idx}")
    print(f"Original Claim: {original_claim}")
    print(f"BM25 Claim: {bm25_claim}")
    print("-----")

print("Test completed!")
# Out:
# Index: 0
# Original Claim: In her budget speech, Nirmala Sitharaman claimed that the Government distributed 35,000 crore LED bulbs in the country.
# BM25 Claim: in her budget speech, nirmala sitharaman claimed that the government distributed 35,000 crore led bulbs in the country
# -----
# Index: 1
# Original Claim: Florida residents affected by Hurricane Irma can receive $197 in food stamp benefits, but only if they can show that their homes lost power for more than two hours.
# BM25 Claim: florida residents affected by hurricane irma can receive $197 in food stamp benefits, but only if they can show that their homes lost power for more than two hours
# -----
# Index: 2
# Original Claim: Bill Gates' foundation tested a polio vaccine in India that left at least 490,000 children paralyzed
# BM25 Claim: bill gates' foundation tested a polio vaccine in india that left at least 490,000 children paralyzed
# -----
# Index: 3
# Original Claim: SaysHillary Clinton "took 13 hours to send help to Americans under fire" during the terrorist attack in Benghazi.
# BM25 Claim: sayshillary clinton "took 13 hours to send help to americans under fire" during the terrorist attack in benghazi
# -----
# Index: 4
# Original Claim: "Send your postcards to 5 key states to decertify fraud” in the 2020 election.
# BM25 Claim: "send your postcards to 5 key states to decertify fraud” in the 2020 election
# -----
# Index: 9930
# Original Claim: Americans "are working longer hours for low wages . . . and yet almost all new income and wealth is going to the top 1 percent."
# BM25 Claim: americans "are working longer hours for low wages    and yet almost all new income and wealth is going to the top 1 percent"
# -----
# Index: 9931
# Original Claim: Two black men, Alize Ramon Smith and Jarron Keonte Moreland of Moore, Oklahoma, were lynched by four white people in April 2018, a crime that was largely ignored by the media.
# BM25 Claim: two black men, alize ramon smith and jarron keonte moreland of moore, oklahoma, were lynched by four white people in april 2018, a crime that was largely ignored by the media
# -----
# Index: 9932
# Original Claim: "Trump just gave a $12 billion bailout to farmers hurt by his failed tariffs. This will cost every household in the U.S. $95 … Trump is borrowing the money from China since his tax cuts blew a trillion dollar hole in the deficit."
# BM25 Claim: "trump just gave a $12 billion bailout to farmers hurt by his failed tariffs this will cost every household in the us $95 … trump is borrowing the money from china since his tax cuts blew a trillion dollar hole in the deficit"
# -----
# Index: 9933
# Original Claim: "Hillary [Clinton] wants to raise taxes by over a trillion dollars."
# BM25 Claim: "hillary [clinton] wants to raise taxes by over a trillion dollars"
# -----
# Index: 9934
# Original Claim: FAKE:  Commandos from &#8220;Berkut&#8221; who refused to kneel have been burned alive in Lviv
# BM25 Claim: fake:  commandos from &#8220;berkut&#8221; who refused to kneel have been burned alive in lviv
# -----
# Index: 9916
# Original Claim: States are seeing increases in revenue, with an average decline of just 0.12% compared with 2019. Over half of states report positive growth, including California, New York, and Illinois.
# BM25 Claim: states are seeing increases in revenue, with an average decline of just 012% compared with 2019 over half of states report positive growth, including california, new york, and illinois
# -----
# Index: 7050
# Original Claim: Says the governors of Michigan, New York and Nevada “have issued orders banning the prescription of hydroxychloroquine to patients with COVID-19.”
# BM25 Claim: says the governors of michigan, new york and nevada “have issued orders banning the prescription of hydroxychloroquine to patients with covid-19”
# -----
# Index: 3998
# Original Claim: A recent Gallup poll found that 72 percent of Americans and 56 percent of Democrats "say the biggest threat to our nation's security is big government."
# BM25 Claim: a recent gallup poll found that 72 percent of americans and 56 percent of democrats "say the biggest threat to our nation's security is big government"
# -----
# Index: 467
# Original Claim: "Less than 10% of the funds allocated to education in the period, representing N3.5 trillion, had been given to the sector."
# BM25 Claim: "less than 10% of the funds allocated to education in the period, representing n35 trillion, had been given to the sector"
# -----
# Index: 8408
# Original Claim: A new 10-foot wall in front of the Federal Reserve building in Washington is a sign that the building is preparing for protests in response to rising interest rates.
# BM25 Claim: a new 10-foot wall in front of the federal reserve building in washington is a sign that the building is preparing for protests in response to rising interest rates
# -----
# Test completed!

# %%
import json
import re
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
from tqdm import tqdm

def preprocess_text(text):
    text = text.lower()
    text = re.sub(r'\s\.\.\.', '', text)
    text = re.sub(r'\.', '', text)
    text = text.split(" ")
    return text

def match_and_order_claims(claims_file, bm25_file, output_file):
    # Load the JSON files
    with open(claims_file, 'r') as file:
        claims = json.load(file)

    with open(bm25_file, 'r') as file:
        bm25_features = json.load(file)

    # Create a dictionary for fast lookup of bm25 claims
    bm25_dict = {}
    for entry in bm25_features:
        claim = entry.split("[Claim]:")[1].split("[Evidences]")[0].strip()
        preprocessed_claim = " ".join(preprocess_text(claim))
        bm25_dict[preprocessed_claim] = entry

    # Prepare the ordered bm25 features list with placeholders
    ordered_bm25_features = [None] * len(claims)
    unmatched_claims = []

    for i, claim in tqdm(enumerate(claims)):
        original_claim = claim["claim"]
        preprocessed_claim = " ".join(preprocess_text(original_claim))
        bm25_entry = bm25_dict.get(preprocessed_claim)
        if bm25_entry:
            ordered_bm25_features[i] = bm25_entry
        else:
            unmatched_claims.append((i, original_claim, preprocessed_claim))

    # Handle unmatched claims using fuzzy matching
    if unmatched_claims:
        bm25_claims = list(bm25_dict.keys())
        for index, original_claim, preprocessed_claim in tqdm(unmatched_claims):
            match, score = process.extractOne(preprocessed_claim, bm25_claims, scorer=fuzz.token_sort_ratio)
            if score > 80:  # Adjust the threshold as needed
                ordered_bm25_features[index] = bm25_dict[match]
                bm25_claims.remove(match)  # Remove the matched claim to avoid duplicates
            else:
                print(f"Warning: No good match found for claim: {original_claim}")

    # Fill remaining None slots with unmatched bm25 features
    remaining_bm25_entries = [entry for entry in bm25_features if entry not in ordered_bm25_features]
    for i, entry in tqdm(enumerate(ordered_bm25_features)):
        if entry is None and remaining_bm25_entries:
            ordered_bm25_features[i] = remaining_bm25_entries.pop(0)

    # Save the ordered bm25 features to a new file
    with open(output_file, 'w') as file:
        json.dump(ordered_bm25_features, file)

    print(f"Ordered BM25 features file created successfully at {output_file}!")
# Out:
# /usr/local/lib/python3.10/dist-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
# Process and match for train set
match_and_order_claims(
    '/content/drive/MyDrive/TUDelft/NLP Group Project/data/train_claims_quantemp.json',
    '/content/drive/MyDrive/TUDelft/NLP Group Project/bm25/bm25_features_train_set.json',
    '/content/drive/MyDrive/TUDelft/NLP Group Project/bm25/ordered_bm25_features_train_set.json'
)

# %%
# Process and match for val set
match_and_order_claims(
    '/content/drive/MyDrive/TUDelft/NLP Group Project/data/val_claims_quantemp.json',
    '/content/drive/MyDrive/TUDelft/NLP Group Project/bm25/bm25_features_val_set.json',
    '/content/drive/MyDrive/TUDelft/NLP Group Project/bm25/ordered_bm25_features_val_set.json'
)
# Out:
# 3084it [00:00, 50262.22it/s]
# 100%|██████████| 7/7 [00:17<00:00,  2.45s/it]
# 3084it [00:00, 1773164.30it/s]
# Ordered BM25 features file created successfully at /content/drive/MyDrive/TUDelft/NLP Group Project/bm25/ordered_bm25_features_val_set.json!

# %%
# Process and match for test set
match_and_order_claims(
    '/content/drive/MyDrive/TUDelft/NLP Group Project/data/test_claims_quantemp.json',
    '/content/drive/MyDrive/TUDelft/NLP Group Project/bm25/unordered_bm25_features_test_set.json',
    '/content/drive/MyDrive/TUDelft/NLP Group Project/bm25/ordered_bm25_features_test_set.json'
)
# Out:
# 2495it [00:00, 124869.20it/s]
#  30%|███       | 3/10 [00:07<00:21,  3.08s/it]
# Warning: No good match found for claim: Multinational technology companies Facebook and Google have opened in Nigeria and the world's largest brewer Anheuser-Busch InBev and multinational food manufacturing giant Kellogg's have established their multibillion-naira brewery and factory in Nigeria
#  40%|████      | 4/10 [00:11<00:19,  3.23s/it]
# Warning: No good match found for claim: "The downsizing of Pinellas County government resulted in about 1,200 people being laid off in a 12 percent unemployment market. … I can tell you that every one of them was hired from the time that Ms. Latvala went into office in 2000."
#  50%|█████     | 5/10 [00:13<00:14,  2.90s/it]
# Warning: No good match found for claim: “For every one person receiving treatment [in 2000], there are 17 who have it today. That means we have increased 17 times at least, the number of people treated.”
#  60%|██████    | 6/10 [00:17<00:13,  3.38s/it]
# Warning: No good match found for claim: "While (Charlie Crist) was governor, utility costs went up 30 percent and went from below the national average to above the national average. Since I got elected, utility rates have come down 11 percent and now we are below the average."
# 100%|██████████| 10/10 [00:23<00:00,  2.40s/it]
# 2495it [00:00, 612262.37it/s]
# Ordered BM25 features file created successfully at /content/drive/MyDrive/TUDelft/NLP Group Project/bm25/ordered_bm25_features_test_set.json!

# %% [markdown]
# ### Test if order is good now

# %%
import random

def test_ordered_claims(claims_file, ordered_bm25_file):
    # Load the JSON files
    with open(claims_file, 'r') as file:
        claims = json.load(file)

    with open(ordered_bm25_file, 'r') as file:
        ordered_bm25_features = json.load(file)

    assert len(claims) == len(ordered_bm25_features), "Lengths do not match!"

    # Function to extract claim from bm25 entry
    def extract_claim(bm25_entry):
        return bm25_entry.split("[Claim]:")[1].split("[Evidences]")[0].strip()

    # Indices to check: first few, last few, and 5 random
    indices_to_check = list(range(5)) + list(range(len(claims) - 5, len(claims)))
    indices_to_check += random.sample(range(5, len(claims) - 5), 5)

    # Check and print claims
    for idx in indices_to_check:
        original_claim = claims[idx]["claim"]
        bm25_entry = ordered_bm25_features[idx]
        bm25_claim = extract_claim(bm25_entry)

        print(f"Index: {idx}")
        print(f"Original Claim: {original_claim}")
        print(f"BM25 Claim: {bm25_claim}")
        print("-----")

    print("Test completed!")

# %%
# Test for train set
test_ordered_claims(
    '/content/drive/MyDrive/TUDelft/NLP Group Project/data/train_claims_quantemp.json',
    '/content/drive/MyDrive/TUDelft/NLP Group Project/bm25/bm25_features_train_set.json'
)

# Test for val set
test_ordered_claims(
    '/content/drive/MyDrive/TUDelft/NLP Group Project/data/val_claims_quantemp.json',
    '/content/drive/MyDrive/TUDelft/NLP Group Project/bm25/bm25_features_val_set.json'
)

# Test for test set
test_ordered_claims(
    '/content/drive/MyDrive/TUDelft/NLP Group Project/data/test_claims_quantemp.json',
    '/content/drive/MyDrive/TUDelft/NLP Group Project/bm25/bm25_features_test_set.json'
)
# Out:
# Index: 0
# Original Claim: In her budget speech, Nirmala Sitharaman claimed that the Government distributed 35,000 crore LED bulbs in the country.
# BM25 Claim: in her budget speech, nirmala sitharaman claimed that the government distributed 35,000 crore led bulbs in the country
# -----
# Index: 1
# Original Claim: Florida residents affected by Hurricane Irma can receive $197 in food stamp benefits, but only if they can show that their homes lost power for more than two hours.
# BM25 Claim: florida residents affected by hurricane irma can receive $197 in food stamp benefits, but only if they can show that their homes lost power for more than two hours
# -----
# Index: 2
# Original Claim: Bill Gates' foundation tested a polio vaccine in India that left at least 490,000 children paralyzed
# BM25 Claim: bill gates' foundation tested a polio vaccine in india that left at least 490,000 children paralyzed
# -----
# Index: 3
# Original Claim: SaysHillary Clinton "took 13 hours to send help to Americans under fire" during the terrorist attack in Benghazi.
# BM25 Claim: sayshillary clinton "took 13 hours to send help to americans under fire" during the terrorist attack in benghazi
# -----
# Index: 4
# Original Claim: "Send your postcards to 5 key states to decertify fraud” in the 2020 election.
# BM25 Claim: "send your postcards to 5 key states to decertify fraud” in the 2020 election
# -----
# Index: 9930
# Original Claim: Americans "are working longer hours for low wages . . . and yet almost all new income and wealth is going to the top 1 percent."
# BM25 Claim: americans "are working longer hours for low wages    and yet almost all new income and wealth is going to the top 1 percent"
# -----
# Index: 9931
# Original Claim: Two black men, Alize Ramon Smith and Jarron Keonte Moreland of Moore, Oklahoma, were lynched by four white people in April 2018, a crime that was largely ignored by the media.
# BM25 Claim: two black men, alize ramon smith and jarron keonte moreland of moore, oklahoma, were lynched by four white people in april 2018, a crime that was largely ignored by the media
# -----
# Index: 9932
# Original Claim: "Trump just gave a $12 billion bailout to farmers hurt by his failed tariffs. This will cost every household in the U.S. $95 … Trump is borrowing the money from China since his tax cuts blew a trillion dollar hole in the deficit."
# BM25 Claim: "trump just gave a $12 billion bailout to farmers hurt by his failed tariffs this will cost every household in the us $95 … trump is borrowing the money from china since his tax cuts blew a trillion dollar hole in the deficit"
# -----
# Index: 9933
# Original Claim: "Hillary [Clinton] wants to raise taxes by over a trillion dollars."
# BM25 Claim: "hillary [clinton] wants to raise taxes by over a trillion dollars"
# -----
# Index: 9934
# Original Claim: FAKE:  Commandos from &#8220;Berkut&#8221; who refused to kneel have been burned alive in Lviv
# BM25 Claim: fake:  commandos from &#8220;berkut&#8221; who refused to kneel have been burned alive in lviv
# -----
# Index: 7383
# Original Claim: Did Kenya's defence minister admit opposition leader Raila Odinga won the 2022 presidential election? No, video has been edited
# BM25 Claim: did kenya's defence minister admit opposition leader raila odinga won the 2022 presidential election? no, video has been edited
# -----
# Index: 4418
# Original Claim: "[A]t his current rate, President Obama will have added more debt to the United State of America by the end of his first term than each of the previous 43 presidents -- combined!"
# BM25 Claim: "[a]t his current rate, president obama will have added more debt to the united state of america by the end of his first term than each of the previous 43 presidents -- combined!"
# -----
# Index: 7782
# Original Claim: No, Nigerian senator Ike Ekweremadu not 'serving 10-year jail term' in the UK, yet to be sentenced
# BM25 Claim: no, nigerian senator ike ekweremadu not 'serving 10-year jail term' in the uk, yet to be sentenced
# -----
# Index: 8939
# Original Claim: A video shows Nancy Pelosi drunkenly slurring her speech during an event in May 2019.
# BM25 Claim: a video shows nancy pelosi drunkenly slurring her speech during an event in may 2019
# -----
# Index: 8188
# Original Claim: 2 BJP leaders arrested for aiding Maoists in their attack in Chhattisgarh
# BM25 Claim: 2 bjp leaders arrested for aiding maoists in their attack in chhattisgarh
# -----
# Test completed!
# Index: 0
# Original Claim: Amit Shah said Narendra Modi sleeps for 24 hours for the welfare of the poor.
# BM25 Claim: amit shah said narendra modi sleeps for 24 hours for the welfare of the poor
# -----
# Index: 1
# Original Claim: Video of show Pakistani players celebrating the rain-hit match against India in Asia Cup 2023
# BM25 Claim: video of show pakistani players celebrating the rain-hit match against india in asia cup 2023
# -----
# Index: 2
# Original Claim: Says Dino Rossi "stripped" health care "from 45,000 children."
# BM25 Claim: says dino rossi "stripped" health care "from 45,000 children"
# -----
# Index: 3
# Original Claim: Durch einen Vergleich mit den Symptomen einer Covid-19-Erkrankung entsteht der Eindruck, die Impfung von Biontech/Pfizer verursache ähnliche oder gar schlimmere Symptome als Covid-19. Der Impfstoff sei zudem laut der U.S. Food and Drug Administration (FDA) nicht zugelassen.
# BM25 Claim: durch einen vergleich mit den symptomen einer covid-19-erkrankung entsteht der eindruck, die impfung von biontech/pfizer verursache ähnliche oder gar schlimmere symptome als covid-19 der impfstoff sei zudem laut der us food and drug administration (fda) nicht zugelassen
# -----
# Index: 4
# Original Claim: A gun-toting Australian granny blew the testicles off the two men who raped her granddaughter.
# BM25 Claim: a gun-toting australian granny blew the testicles off the two men who raped her granddaughter
# -----
# Index: 3079
# Original Claim: Mark Zuckerberg is giving $1,000 away to Facebook users who refrain from sharing hoaxes.
# BM25 Claim: mark zuckerberg is giving $1,000 away to facebook users who refrain from sharing hoaxes
# -----
# Index: 3080
# Original Claim: Joe Biden said Democrats would cheat in 2022 by dumping ballots
# BM25 Claim: joe biden said democrats would cheat in 2022 by dumping ballots
# -----
# Index: 3081
# Original Claim: "CNN to permanently close its doors as ratings plunge 30 percent."
# BM25 Claim: "cnn to permanently close its doors as ratings plunge 30 percent"
# -----
# Index: 3082
# Original Claim: A recent study found "that cities where Uber operates have 3.6%-5.6% fewer drunk driving deaths than cities without access to ridesharing."
# BM25 Claim: a recent study found "that cities where uber operates have 36%-56% fewer drunk driving deaths than cities without access to ridesharing"
# -----
# Index: 3083
# Original Claim: The Biden administration "published a study concluding 4 (of) 5 new cars on the road by 2050 will still require liquid fuels."
# BM25 Claim: the biden administration "published a study concluding 4 (of) 5 new cars on the road by 2050 will still require liquid fuels"
# -----
# Index: 1450
# Original Claim: Says Gov. Rick Scott is "spending a quarter of a million of our tax dollars to robocall people."
# BM25 Claim: says gov rick scott is "spending a quarter of a million of our tax dollars to robocall people"
# -----
# Index: 1321
# Original Claim: House Speaker Dean Cannon says that freshmen lawmakers account for one-third of the 120-member House, and that two-thirds of the chamber have two years or less experience.
# BM25 Claim: house speaker dean cannon says that freshmen lawmakers account for one-third of the 120-member house, and that two-thirds of the chamber have two years or less experience
# -----
# Index: 705
# Original Claim: Palin said stimulus money for weatherization required "universal energy building codes for Alaska, kind of a one-size-fits-all building code that isn't going to work up there in Alaska."
# BM25 Claim: palin said stimulus money for weatherization required "universal energy building codes for alaska, kind of a one-size-fits-all building code that isn't going to work up there in alaska"
# -----
# Index: 410
# Original Claim: 18 nations including USA and UK want PM Modi to lead a coronavirus task force
# BM25 Claim: 18 nations including usa and uk want pm modi to lead a coronavirus task force
# -----
# Index: 2677
# Original Claim: After its theatrical release and initial home video run, Disney deleted a scene from "The Santa Clause" movie that mentioned the phone number 1-800-SPANK-ME.
# BM25 Claim: after its theatrical release and initial home video run, disney deleted a scene from "the santa clause" movie that mentioned the phone number 1-800-spank-me
# -----
# Test completed!
# Index: 0
# Original Claim: "The non-partisan Congressional Budget Office concluded ObamaCare will cost the U.S. more than 800,000 jobs."
# BM25 Claim: "the non-partisan congressional budget office concluded obamacare will cost the us more than 800,000 jobs"
# -----
# Index: 1
# Original Claim: "More than 50 percent of immigrants from (El Salvador, Guatemala and Honduras) use at least one major welfare program once they get here."
# BM25 Claim: "more than 50 percent of immigrants from (el salvador, guatemala and honduras) use at least one major welfare program once they get here"
# -----
# Index: 2
# Original Claim: UK government banned Covid vaccine for children age 5-11
# BM25 Claim: uk government banned covid vaccine for children age 5-11
# -----
# Index: 3
# Original Claim: "[In 2014-2015] coverage for the rotavirus vaccine exceeded the 95% target and the pneumococcal vaccine reached 91.5%."
# BM25 Claim: "[in 2014-2015] coverage for the rotavirus vaccine exceeded the 95% target and the pneumococcal vaccine reached 915%"
# -----
# Index: 4
# Original Claim: In September 2021, the U.K. government announced its intention to create a new criminal offense of pet abduction.
# BM25 Claim: in september 2021, the uk government announced its intention to create a new criminal offense of pet abduction
# -----
# Index: 2490
# Original Claim: An Arizona family preparing for a swim found several rattlesnakes hiding inside two pool noodles stored near their home.
# BM25 Claim: an arizona family preparing for a swim found several rattlesnakes hiding inside two pool noodles stored near their home
# -----
# Index: 2491
# Original Claim: Screenshots that surfaced online in early October 2021 authentically show photographs of, or comments written by, the Zodiac killer.
# BM25 Claim: screenshots that surfaced online in early october 2021 authentically show photographs of, or comments written by, the zodiac killer
# -----
# Index: 2492
# Original Claim: The 1816 death of Gouverneur Morris, a signer of the Constitution, was caused by an infection after his urinary blockage was treated with a whalebone catheter.
# BM25 Claim: the 1816 death of gouverneur morris, a signer of the constitution, was caused by an infection after his urinary blockage was treated with a whalebone catheter
# -----
# Index: 2493
# Original Claim: "Nigeria's doctor-to-population ratio falls far short of the WHO recommended doctor-to-population ratio of 1:600."
# BM25 Claim: "nigeria's doctor-to-population ratio falls far short of the who recommended doctor-to-population ratio of 1:600"
# -----
# Index: 2494
# Original Claim: During the Bharat Jodo Yatra, Rahul Gandhi was seen with Amulya Leona Noronha, the woman who was arrested for saying 'Pakistan Zindabad' during an anti-CAA rally in 2020.
# BM25 Claim: during the bharat jodo yatra, rahul gandhi was seen with amulya leona noronha, the woman who was arrested for saying 'pakistan zindabad' during an anti-caa rally in 2020
# -----
# Index: 1325
# Original Claim: No, Nigeria 2023 election portal does not show Labour Party's Peter Obi as winner, results upload ongoing
# BM25 Claim: no, nigeria 2023 election portal does not show labour party's peter obi as winner, results upload ongoing
# -----
# Index: 761
# Original Claim: Rahul Gandhi has accused PM Modi of lying, claims he himself had laid the foundation stone of the ordinance factory in Amethi in 2010.
# BM25 Claim: rahul gandhi has accused pm modi of lying, claims he himself had laid the foundation stone of the ordinance factory in amethi in 2010
# -----
# Index: 1267
# Original Claim: UN’s new system reclassifies people aged 15 to 65 as ‘youth’
# BM25 Claim: un’s new system reclassifies people aged 15 to 65 as ‘youth’
# -----
# Index: 359
# Original Claim: Photo showing how China tested the capability of a car in 1993
# BM25 Claim: photo showing how china tested the capability of a car in 1993
# -----
# Index: 519
# Original Claim: In November 2021, USA Today published an article that described Kyle Rittenhouse as crying "crocodile tears" and engaging in a "melodramatic performance" during testimony in his trial.
# BM25 Claim: in november 2021, usa today published an article that described kyle rittenhouse as crying "crocodile tears" and engaging in a "melodramatic performance" during testimony in his trial
# -----
# Test completed!

# %% [markdown]
# # Tokenize and save as .pt

# %%
from torch.utils.data import TensorDataset
from tqdm import tqdm
from transformers import AutoTokenizer
import torch
import os
from sklearn.preprocessing import LabelEncoder
def tokenize_and_save_dataset(features, labels, tokenizer_short_name, tokenizer_path, dataset_type, le=None):
    """
    Tokenizes the features and saves the dataset as a PyTorch TensorDataset.

    Args:
    features (list): List of feature strings to tokenize.
    labels (list): List of labels corresponding to the features.
    tokenizer_short_name (str): Short name for the tokenizer to use in the filename.
    tokenizer_path (str): Path or name of the tokenizer model.
    dataset_type (str): The type of dataset (train, val, or test) for naming the file.
    le (LabelEncoder, optional): A fitted LabelEncoder. If None, a new one will be created and fitted to the labels.
    """
    # Load the tokenizer
    tokenizer = AutoTokenizer.from_pretrained(tokenizer_path, do_lower_case=True)

    input_ids = []
    attention_masks = []

    # Tokenize each feature
    for idx, sent in enumerate(tqdm(features, desc=f"Tokenizing {dataset_type} features")):

        encoded_dict = tokenizer.encode_plus(
            sent,
            add_special_tokens=True,
            max_length=256,
            pad_to_max_length=True,
            truncation=True,
            return_attention_mask=True,
            return_tensors='pt',
        )

        input_ids.append(encoded_dict['input_ids'])
        attention_masks.append(encoded_dict['attention_mask'])

    # Convert the lists into tensors
    input_ids = torch.cat(input_ids, dim=0)
    attention_masks = torch.cat(attention_masks, dim=0)

    # Encode the labels
    if le is None:
        le = LabelEncoder()
        labels_final = le.fit_transform(labels)
    else:
        labels_final = le.transform(labels)
    labels_final = torch.tensor(labels_final)

    assert input_ids.shape[0] == attention_masks.shape[0] == labels_final.shape[0], "Size mismatch between inputs and labels"

    # Create TensorDataset
    dataset = TensorDataset(input_ids, attention_masks, labels_final)

    # Save the dataset
    save_file = os.path.join('/content/drive/MyDrive/TUDelft/NLP Group Project/bm25/', f"{dataset_type}_dataset_tokenized_by_{tokenizer_short_name}.pt")
    torch.save(dataset, save_file)
    print(f"{dataset_type.capitalize()} dataset saved to {save_file}")
    return le  # Return the fitted label encoder for reuse

# def tokenize_and_save_dataset(features, labels, tokenizer_short_name, tokenizer_path, dataset_type, le=None):
#     """
#     Tokenizes the features and saves the dataset as a PyTorch TensorDataset.

#     Args:
#     features (list): List of feature strings to tokenize.
#     labels (list): List of labels corresponding to the features.
#     tokenizer_short_name (str): Short name for the tokenizer to use in the filename.
#     tokenizer_path (str): Path or name of the tokenizer model.
#     dataset_type (str): The type of dataset (train, val, or test) for naming the file.
#     le (LabelEncoder, optional): A fitted LabelEncoder. If None, a new one will be created and fitted to the labels.
#     """
#     # Load the tokenizer
#     tokenizer = AutoTokenizer.from_pretrained(tokenizer_path, do_lower_case=True)

#     input_ids = []
#     attention_masks = []

#     # Tokenize each feature
#     for sent in tqdm(features, desc=f"Tokenizing {dataset_type} features"):
#         encoded_dict = tokenizer.encode_plus(
#             sent,
#             add_special_tokens=True,
#             max_length=256,
#             pad_to_max_length=True,
#             truncation=True,
#             return_attention_mask=True,
#             return_tensors='pt',
#         )

#         input_ids.append(encoded_dict['input_ids'])
#         attention_masks.append(encoded_dict['attention_mask'])

#     # Convert the lists into tensors
#     input_ids = torch.cat(input_ids, dim=0)
#     attention_masks = torch.cat(attention_masks, dim=0)

#     # Encode the labels
#     if le is None:
#         le = LabelEncoder()
#         labels_final = le.fit_transform(labels)
#     else:
#         labels_final = le.transform(labels)
#     labels_final = torch.tensor(labels_final)
#     assert input_ids.shape[0] == attention_masks.shape[0] == labels_final.shape[0], "Size mismatch between inputs and labels"

#     # Create TensorDataset
#     dataset = TensorDataset(input_ids, attention_masks, labels_final)

#     # Save the dataset
#     save_file = os.path.join('/content/drive/MyDrive/TUDelft/NLP Group Project/bm25/', f"{dataset_type}_dataset_tokenized_by_{tokenizer_short_name}.pt")
#     torch.save(dataset, save_file)
#     print(f"{dataset_type.capitalize()} dataset saved to {save_file}")
#     return le  # Return the fitted label encoder for reuse

# %%
import math  # Import math module for isnan function

def check_features(features):
    # Check for invalid entries in feature data
    invalid_indices = []
    for idx, feature in enumerate(features):
        if feature is None:
            print(f"Found None at index {idx}", feature)
            invalid_indices.append(idx)
        elif isinstance(feature, float) and math.isnan(feature):  # Checking for NaN in case of float
            print(f"Found NaN at index {idx}", feature)
            invalid_indices.append(idx)
        elif not isinstance(feature, str):  # Ensure each feature is a string
            print(f"Unexpected type at index {idx}: {type(feature)} (value: {feature})")
            invalid_indices.append(idx)

    if not invalid_indices:
        print("All features are valid.")
    else:
        print(f"Invalid entries found at indices: {invalid_indices}")

# Example usage with a sample test_features list

# Call the function to check the test_features
check_features(test_features)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-8c79597e1242> in <cell line: 25>()
#      23
#      24 # Call the function to check the test_features
# ---> 25 check_features(test_features)
#
# NameError: name 'test_features' is not defined

# %% [markdown]
# ### Roberta

# %%
train_labels = [fact["label"] for fact in train_data]

print(train_labels)
le = tokenize_and_save_dataset(
    features=train_features,
    labels=train_labels,
    tokenizer_short_name='roberta',
    tokenizer_path = 'roberta-large-mnli',

    dataset_type='train'
)
val_labels = [fact["label"] for fact in val_data]
tokenize_and_save_dataset(
    features=val_features,
    labels=val_labels,
    tokenizer_short_name='roberta',
    tokenizer_path = 'roberta-large-mnli',

    dataset_type='val',
    le=le  # Use the fitted LabelEncoder from the training set
)
test_labels = [fact["label"] for fact in test_data]
tokenize_and_save_dataset(
    features=test_features,
    labels=test_labels,
    tokenizer_short_name='roberta',
    tokenizer_path = 'roberta-large-mnli',
    dataset_type='test',
    le=le  # Use the fitted LabelEncoder from the training set
)
# Out:
# ['False', 'False', 'False', 'False', 'False', 'Conflicting', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'Conflicting', 'False', 'True', 'True', 'False', 'False', 'Conflicting', 'False', 'False', 'False', 'Conflicting', 'Conflicting', 'False', 'False', 'True', 'False', 'Conflicting', 'True', 'False', 'False', 'Conflicting', 'Conflicting', 'Conflicting', 'Conflicting', 'False', 'False', 'True', 'Conflicting', 'False', 'Conflicting', 'Conflicting', 'False', 'False', 'False', 'False', 'False', 'Conflicting', 'True', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'Conflicting', 'False', 'False', 'Conflicting', 'True', 'True', 'False', 'True', 'True', 'False', 'Conflicting', 'False', 'True', 'False', 'Conflicting', 'Conflicting', 'Conflicting', 'False', 'False', 'False', 'Conflicting', 'True', 'True', 'False', 'False', 'Conflicting', 'True', 'Conflicting', 'Conflicting', 'False', 'False', 'False', 'False', 'Conflicting', 'False', 'False', 'Conflicting', 'False', 'False', 'True', 'False', 'True', 'False', 'True', 'False', 'Conflicting', 'False', 'True', 'Conflicting', 'True', 'Conflicting', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'Conflicting', 'Conflicting', 'Conflicting', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'True', 'False', 'Conflicting', 'Conflicting', 'True', 'Conflicting', 'Conflicting', 'False', 'False', 'True', 'False', 'True', 'False', 'Conflicting', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'Conflicting', 'False', 'False', 'False', 'False', 'Conflicting', 'True', 'True', 'False', 'False', 'False', 'False', 'False', 'Conflicting', 'Conflicting', 'False', 'True', 'Conflicting', 'False', 'True', 'Conflicting', 'False', 'False', 'True', 'True', 'False', 'True', 'False', 'True', 'Conflicting', 'False', 'False', 'Conflicting', 'True', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'False', 'Conflicting', 'False', 'Conflicting', 'False', 'Conflicting', 'False', 'Conflicting', 'True', 'False', 'Conflicting', 'False', 'False', 'True', 'Conflicting', 'Conflicting', 'False', 'True', 'True', 'Conflicting', 'Conflicting', 'False', 'False', 'False', 'False', 'False', 'False', 'Conflicting', 'False', 'Conflicting', 'True', 'False', 'True', 'False', 'False', 'False', 'False', 'True', 'Conflicting', 'Conflicting', 'Conflicting', 'True', 'False', 'True', 'False', 'False', 'False', 'False', 'Conflicting', 'True', 'False', 'Conflicting', 'False', 'False', 'False', 'Conflicting', 'False', 'Conflicting', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'Conflicting', 'False', 'False', 'False', 'False', 'True', 'True', 'False', 'False', 'Conflicting', 'False', 'True', 'False', 'False', 'False', 'False', 'Conflicting', 'True', 'Conflicting', 'False', 'False', 'False', 'False', 'False', 'Conflicting', 'False', 'False', 'Conflicting', 'True', 'True', 'False', 'Conflicting', 'False', 'True', 'False', 'True', 'False', 'Conflicting', 'False', 'Conflicting', 'False', 'Conflicting', 'True', 'Conflicting', 'False', 'Conflicting', 'False', 'False', 'True', 'Conflicting', 'False', 'Conflicting', 'Conflicting', 'False', 'False', 'False', 'False', 'True', 'False', 'True', 'False', 'Conflicting', 'False', 'False', 'False', 'False', 'True', 'True', 'Conflicting', 'True', 'False', 'True', 'False', 'Conflicting', 'False', 'Conflicting', 'Conflicting', 'True', 'False', 'False', 'True', 'False', 'False', 'Conflicting', 'False', 'True', 'False', 'False', 'True', 'False', 'Conflicting', 'Conflicting', 'True', 'False', 'True', 'False', 'False', 'False', 'True', 'True', 'False', 'False', 'True', 'True', 'True', 'Conflicting', 'False', 'False', 'Conflicting', 'False', 'False', 'True', 'Conflicting', 'False', 'True', 'False', 'False', 'Conflicting', 'False', 'False', 'Conflicting', 'False', 'Conflicting ...
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/688 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Tokenizing train features:   0%|          | 0/9935 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:2699: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# Tokenizing train features: 100%|██████████| 9935/9935 [00:09<00:00, 999.44it/s]
# Train dataset saved to /content/drive/MyDrive/TUDelft/NLP Group Project/bm25/train_dataset_tokenized_by_robertaaaa.pt
# Tokenizing val features:   0%|          | 0/3084 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:2699: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# Tokenizing val features: 100%|██████████| 3084/3084 [00:04<00:00, 706.75it/s]
# Val dataset saved to /content/drive/MyDrive/TUDelft/NLP Group Project/bm25/val_dataset_tokenized_by_robertaaaa.pt
# Tokenizing test features:   0%|          | 0/2495 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:2699: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# Tokenizing test features: 100%|██████████| 2495/2495 [00:03<00:00, 785.52it/s]
# Test dataset saved to /content/drive/MyDrive/TUDelft/NLP Group Project/bm25/test_dataset_tokenized_by_roberta.pt
# LabelEncoder()

# %% [markdown]
# ### Mdeberta

# %%
train_labels = [fact["label"] for fact in train_data]
le = tokenize_and_save_dataset(
    features=train_features,
    labels=train_labels,
    tokenizer_short_name='mdeberta',
    tokenizer_path='MoritzLaurer/mDeBERTa-v3-base-xnli-multilingual-nli-2mil7',
    dataset_type='train'
)
val_labels = [fact["label"] for fact in val_data]
tokenize_and_save_dataset(
    features=val_features,
    labels=val_labels,
    tokenizer_short_name='mdeberta',
    tokenizer_path='MoritzLaurer/mDeBERTa-v3-base-xnli-multilingual-nli-2mil7',
    dataset_type='val',
    le=le  # Use the fitted LabelEncoder from the training set
)
test_labels = [fact["label"] for fact in test_data]
tokenize_and_save_dataset(
    features=test_features,
    labels=test_labels,
    tokenizer_short_name='mdeberta',
    tokenizer_path='MoritzLaurer/mDeBERTa-v3-base-xnli-multilingual-nli-2mil7',
    dataset_type='test',
    le=le  # Use the fitted LabelEncoder from the training set
)
# Out:
# tokenizer_config.json:   0%|          | 0.00/467 [00:00<?, ?B/s]
# spm.model:   0%|          | 0.00/4.31M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/16.3M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/23.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/173 [00:00<?, ?B/s]
# Tokenizing train features:   0%|          | 0/9935 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:2699: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# Tokenizing train features: 100%|██████████| 9935/9935 [00:13<00:00, 732.43it/s]
# Train dataset saved to /content/drive/MyDrive/TUDelft/NLP Group Project/bm25/train_dataset_tokenized_by_mdeberta.pt
# Tokenizing val features:   0%|          | 0/3084 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:2699: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# Tokenizing val features: 100%|██████████| 3084/3084 [00:04<00:00, 628.30it/s]
# Val dataset saved to /content/drive/MyDrive/TUDelft/NLP Group Project/bm25/val_dataset_tokenized_by_mdeberta.pt
# Tokenizing test features:   0%|          | 0/2495 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:2699: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# Tokenizing test features: 100%|██████████| 2495/2495 [00:04<00:00, 536.83it/s]
# Test dataset saved to /content/drive/MyDrive/TUDelft/NLP Group Project/bm25/test_dataset_tokenized_by_mdeberta.pt
# LabelEncoder()

# %% [markdown]
# ### Bart

# %%
train_labels = [fact["label"] for fact in train_data]
le = tokenize_and_save_dataset(
    features=train_features,
    labels=train_labels,
    tokenizer_short_name='bart',
    tokenizer_path='facebook/bart-large-mnli',
    dataset_type='train'
)
val_labels = [fact["label"] for fact in val_data]
tokenize_and_save_dataset(
    features=val_features,
    labels=val_labels,
    tokenizer_short_name='bart',
    tokenizer_path='facebook/bart-large-mnli',
    dataset_type='val',
    le=le  # Use the fitted LabelEncoder from the training set
)
test_labels = [fact["label"] for fact in test_data]
tokenize_and_save_dataset(
    features=test_features,
    labels=test_labels,
    tokenizer_short_name='bart',
    tokenizer_path='facebook/bart-large-mnli',
    dataset_type='test',
    le=le  # Use the fitted LabelEncoder from the training set
)
# Out:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.15k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Tokenizing train features:   0%|          | 0/9935 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:2699: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# Tokenizing train features: 100%|██████████| 9935/9935 [00:11<00:00, 859.41it/s]
# Train dataset saved to /content/drive/MyDrive/TUDelft/NLP Group Project/bm25/train_dataset_tokenized_by_bart.pt
# Tokenizing val features:   0%|          | 0/3084 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:2699: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# Tokenizing val features: 100%|██████████| 3084/3084 [00:03<00:00, 944.54it/s]
# Val dataset saved to /content/drive/MyDrive/TUDelft/NLP Group Project/bm25/val_dataset_tokenized_by_bart.pt
# Tokenizing test features:   0%|          | 0/2495 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:2699: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# Tokenizing test features: 100%|██████████| 2495/2495 [00:04<00:00, 561.61it/s]
# Test dataset saved to /content/drive/MyDrive/TUDelft/NLP Group Project/bm25/test_dataset_tokenized_by_bart.pt
# LabelEncoder()

# %% [markdown]
# ### Deberta

# %%
train_labels = [fact["label"] for fact in train_data]
le = tokenize_and_save_dataset(
    features=train_features,
    labels=train_labels,
    tokenizer_short_name='deberta',
    tokenizer_path='sileod/deberta-v3-base-tasksource-nli',
    dataset_type='train'
)
val_labels = [fact["label"] for fact in val_data]
tokenize_and_save_dataset(
    features=val_features,
    labels=val_labels,
    tokenizer_short_name='deberta',
    tokenizer_path='sileod/deberta-v3-base-tasksource-nli',
    dataset_type='val',
    le=le  # Use the fitted LabelEncoder from the training set
)
test_labels = [fact["label"] for fact in test_data]
tokenize_and_save_dataset(
    features=test_features,
    labels=test_labels,
    tokenizer_short_name='deberta',
    tokenizer_path='sileod/deberta-v3-base-tasksource-nli',
    dataset_type='test',
    le=le  # Use the fitted LabelEncoder from the training set
)
# Out:
# Tokenizing train features:   0%|          | 0/9935 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:2699: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# Tokenizing train features: 100%|██████████| 9935/9935 [00:13<00:00, 742.76it/s]
# Train dataset saved to /content/drive/MyDrive/TUDelft/NLP Group Project/bm25/train_dataset_tokenized_by_deberta.pt
# Tokenizing val features:   0%|          | 0/3084 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:2699: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# Tokenizing val features: 100%|██████████| 3084/3084 [00:03<00:00, 838.49it/s]
# Val dataset saved to /content/drive/MyDrive/TUDelft/NLP Group Project/bm25/val_dataset_tokenized_by_deberta.pt
# Tokenizing test features:   0%|          | 0/2495 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:2699: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# Tokenizing test features: 100%|██████████| 2495/2495 [00:03<00:00, 720.81it/s]
# Test dataset saved to /content/drive/MyDrive/TUDelft/NLP Group Project/bm25/test_dataset_tokenized_by_deberta.pt
# LabelEncoder()

# %% [markdown]
# ### PASTA

# %%
train_labels = [fact["label"] for fact in train_data]
le = tokenize_and_save_dataset(
    features=train_features,
    labels=train_labels,
    tokenizer_short_name='pasta',
    tokenizer_path='microsoft/deberta-v3-large',
    dataset_type='train'
)
val_labels = [fact["label"] for fact in val_data]
tokenize_and_save_dataset(
    features=val_features,
    labels=val_labels,
    tokenizer_short_name='pasta',
    tokenizer_path='microsoft/deberta-v3-large',
    dataset_type='val',
    le=le  # Use the fitted LabelEncoder from the training set
)
test_labels = [fact["label"] for fact in test_data]
tokenize_and_save_dataset(
    features=test_features,
    labels=test_labels,
    tokenizer_short_name='pasta',
    tokenizer_path='microsoft/deberta-v3-large',
    dataset_type='test',
    le=le  # Use the fitted LabelEncoder from the training set
)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/580 [00:00<?, ?B/s]
# spm.model:   0%|          | 0.00/2.46M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/convert_slow_tokenizer.py:560: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(
# Tokenizing train features:   0%|          | 0/9935 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:2699: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# Tokenizing train features: 100%|██████████| 9935/9935 [00:21<00:00, 462.90it/s]
# Train dataset saved to /content/drive/MyDrive/TUDelft/NLP Group Project/bm25/train_dataset_tokenized_by_pasta.pt
# /usr/local/lib/python3.10/dist-packages/transformers/convert_slow_tokenizer.py:560: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(
# Tokenizing val features:   0%|          | 0/3084 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:2699: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# Tokenizing val features: 100%|██████████| 3084/3084 [00:05<00:00, 526.82it/s]
# Val dataset saved to /content/drive/MyDrive/TUDelft/NLP Group Project/bm25/val_dataset_tokenized_by_pasta.pt
# /usr/local/lib/python3.10/dist-packages/transformers/convert_slow_tokenizer.py:560: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(
# Tokenizing test features:   0%|          | 0/2495 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:2699: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(
# Tokenizing test features: 100%|██████████| 2495/2495 [00:07<00:00, 338.58it/s]
# Test dataset saved to /content/drive/MyDrive/TUDelft/NLP Group Project/bm25/test_dataset_tokenized_by_pasta.pt
# LabelEncoder()

# %% [markdown]
# # Training setup

# %%
# Load the BM25 datasets from the file
dataset = torch.load('/content/drive/MyDrive/TUDelft/NLP Group Project/bm25/train_dataset_tokenized_by_deberta.pt')
val_dataset = torch.load('/content/drive/MyDrive/TUDelft/NLP Group Project/bm25/val_dataset_tokenized_by_deberta.pt')

print("Datasets loaded successfully.")
# Out:
# Datasets loaded successfully.

# %%
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler
batch_size = 16
train_dataloader = DataLoader(
            dataset,  # The training samples.
            sampler = RandomSampler(dataset), # Select batches randomly
            batch_size = batch_size # Trains with this batch size.
        )

validation_dataloader = DataLoader(
            val_dataset, # The validation samples.
            sampler = SequentialSampler(val_dataset),
            batch_size = batch_size
        )

# %%
from torch import nn
class MultiClassClassifier(nn.Module):
    def __init__(self, model_path, labels_count, hidden_dim=768, mlp_dim=500, extras_dim=100, dropout=0.1, freeze_bert=False):
        super().__init__()

        self.nlimodel = AutoModel.from_pretrained(model_path,output_hidden_states=True,output_attentions=True)

        self.dropout = nn.Dropout(dropout)
        self.mlp = nn.Sequential(
#             nn.Linear(hidden_dim, mlp_dim),
            # input is of shape [batch_size, 256, 768]
            nn.Linear(mlp_dim, hidden_dim),
            nn.ReLU(),
            # nn.Linear(mlp_dim, mlp_dim),
            # # nn.ReLU(),
            # # nn.Linear(mlp_dim, mlp_dim),
            # nn.ReLU(),
            nn.Linear(hidden_dim, labels_count)
        )
        '''
        hidden_dim = 1024
        mlp_dim=768
        extras_dim=140
        MLP Input Shape : torch.Size([16, 256, 768])

        nn linear - (in_features, out_features)

        nn linear1 = (1024, 768)
        0.weight torch.Size([768, 1024])
        0.bias torch.Size([768])
        2.weight torch.Size([3, 768])
        2.bias torch.Size([3])
        '''

        self.softmax = nn.LogSoftmax(dim=1)
        if freeze_bert:
            print("Freezing layers")
            for param in self.nlimodel.parameters():
                param.requires_grad = False

    def forward(self, tokens, masks):
#         Input IDs / Tokens : torch.Size([16, 256])
#         Masks : torch.Size([16, 256])

        output = self.nlimodel(tokens, attention_mask=masks)
        # output is a dictionary

        # output keys = dict_keys(['last_hidden_state', 'hidden_states', 'attentions'])
        # each hidden state has shape [batch_size, 256, 768]
        # OUTPUT OF ROBERTA IS [batch_size, 1024]
        # each attention mask has shape [batch_size, 12, 256, 256]



        '''
        # Approach that pools the last hidden state
        # [batch_size, 256, 768] -> [batch_size, 768]

        dropout_output = self.dropout(output["last_hidden_state"])
        dropout_output = torch.mean(dropout_output, dim=1)
        '''
        # [CLS] token is usually in the first position
        dropout_output = self.dropout(output["last_hidden_state"][:, 0, :])




        # concat_output = torch.cat((dropout_output, topic_emb), dim=1)
        # concat_output = self.dropout(concat_output)



        mlp_output = self.mlp(dropout_output)
        proba = self.softmax(mlp_output)

        return mlp_output

# %%
from transformers import BertForSequenceClassification, AdamW, BertConfig

# Loads BertForSequenceClassification, the pretrained BERT model with a single
num_classes = 3
model = MultiClassClassifier('sileod/deberta-v3-base-tasksource-nli',num_classes, 1024,768,140,dropout=0.1,freeze_bert=False)

# model.load_state_dict(torch.load("model_bert_difficulty_prediction/model_weights"))

# Tell pytorch to run this model on the GPU.
model.cuda()
# Out:
# config.json:   0%|          | 0.00/18.5k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/738M [00:00<?, ?B/s]
# MultiClassClassifier(
#   (nlimodel): DebertaV2Model(
#     (embeddings): DebertaV2Embeddings(
#       (word_embeddings): Embedding(128100, 768, padding_idx=0)
#       (LayerNorm): LayerNorm((768,), eps=1e-07, elementwise_affine=True)
#       (dropout): StableDropout()
#     )
#     (encoder): DebertaV2Encoder(
#       (layer): ModuleList(
#         (0-11): 12 x DebertaV2Layer(
#           (attention): DebertaV2Attention(
#             (self): DisentangledSelfAttention(
#               (query_proj): Linear(in_features=768, out_features=768, bias=True)
#               (key_proj): Linear(in_features=768, out_features=768, bias=True)
#               (value_proj): Linear(in_features=768, out_features=768, bias=True)
#               (pos_dropout): StableDropout()
#               (dropout): StableDropout()
#             )
#             (output): DebertaV2SelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-07, elementwise_affine=True)
#               (dropout): StableDropout()
#             )
#           )
#           (intermediate): DebertaV2Intermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): DebertaV2Output(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-07, elementwise_affine=True)
#             (dropout): StableDropout()
#           )
#         )
#       )
#       (rel_embeddings): Embedding(512, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-07, elementwise_affine=True)
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (mlp): Sequential(
#     (0): Linear(in_features=768, out_features=1024, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=1024, out_features=3, bias=True)
#   )
#   (softmax): LogSoftmax(dim=1)
# )

# %% [markdown]
# ## Setting up training loop

# %%
optimizer = AdamW(model.parameters(),
                  lr = 2e-5,
                  eps = 1e-8 # args.adam_epsilon  - default is 1e-8.
                )
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:588: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %%
from transformers import get_linear_schedule_with_warmup


epochs = 20

# Total number of training steps is [number of batches] x [number of epochs].
total_steps = len(train_dataloader) * epochs

# %%
len(train_dataloader)
# Out:
# 621

# %%
1935 * 32
# Out:
# 61920

# %%
scheduler = get_linear_schedule_with_warmup(optimizer,
                                            num_warmup_steps = 0, # Default value in run_glue.py
                                            num_training_steps = total_steps)

# %%
import numpy as np

# Function to calculate the accuracy of our predictions vs labels
def flat_accuracy(preds, labels):
    pred_flat = np.argmax(preds, axis=1).flatten()
    labels_flat = labels.flatten()
    return np.sum(pred_flat == labels_flat) / len(labels_flat)

# %%
import time
import datetime

def format_time(elapsed):
    '''
    Takes a time in seconds and returns a string hh:mm:ss
    '''
    # Round to the nearest second.
    elapsed_rounded = int(round((elapsed)))

    # Format as hh:mm:ss
    return str(datetime.timedelta(seconds=elapsed_rounded))

# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"

# %%
class EarlyStopping:
    """Early stops the training if validation loss doesn't improve after a given patience."""
    def __init__(self, patience=7, verbose=False, delta=0, path='checkpoint.pt', trace_func=print):
        """
        Args:
            patience (int): How long to wait after last time validation loss improved.
                            Default: 7
            verbose (bool): If True, prints a message for each validation loss improvement.
                            Default: False
            delta (float): Minimum change in the monitored quantity to qualify as an improvement.
                            Default: 0
            path (str): Path for the checkpoint to be saved to.
                            Default: 'checkpoint.pt'
            trace_func (function): trace print function.
                            Default: print
        """
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta
        self.path = path
        self.trace_func = trace_func
    def __call__(self, val_loss, model):

        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            self.trace_func(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        '''Saves model when validation loss decrease.'''
        if self.verbose:
            self.trace_func(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), self.path)
        self.val_loss_min = val_loss

# %%
for param in model.nlimodel.encoder.layer[0:5].parameters():
    param.requires_grad=False

# %%
loss_func = nn.CrossEntropyLoss()

# %% [markdown]
# # Training

# %%
import random
import numpy as np

# This training code is based on the `run_glue.py` script here:
# https://github.com/huggingface/transformers/blob/5bfcd0485ece086ebcbed2d008813037968a9e58/examples/run_glue.py#L128

# Set the seed value all over the place to make this reproducible.
seed_val = 42

random.seed(seed_val)
np.random.seed(seed_val)
torch.manual_seed(seed_val)
torch.cuda.manual_seed_all(seed_val)

# We'll store a number of quantities such as training and validation loss,
# validation accuracy, and timings.
training_stats = []

# Measure the total training time for the whole run.
total_t0 = time.time()
early_stopping = EarlyStopping(patience=2, verbose=True)
# For each epoch...
for epoch_i in range(0, epochs):

    # ========================================
    #               Training
    # ========================================

    # Perform one full pass over the training set.

    print("")
    print('======== Epoch {:} / {:} ========'.format(epoch_i + 1, epochs))
    print('Training...')

    # Measure how long the training epoch takes.
    t0 = time.time()

    # Reset the total loss for this epoch.
    total_train_accuracy = 0
    total_train_loss = 0

    # Put the model into training mode. Don't be mislead--the call to
    # `train` just changes the *mode*, it doesn't *perform* the training.
    # `dropout` and `batchnorm` layers behave differently during training
    # vs. test (source: https://stackoverflow.com/questimport gensim.downloader as api
    model.train()

    # For each batch of training data...
    for step, batch in enumerate(train_dataloader):

        # Progress update every 40 batches.
        if step % 40 == 0 and not step == 0:
            # Calculate elapsed time in minutes.
            elapsed = format_time(time.time() - t0)

            # Report progress.
            print('  Batch {:>5,}  of  {:>5,}.    Elapsed: {:}.'.format(step, len(train_dataloader), elapsed))

        # Unpack this training batch from our dataloader.
        #
        # As we unpack the batch, we'll also copy each tensor to the GPU using the
        # `to` method.
        #
        # `batch` contains three pytorch tensors:
        #   [0]: input ids
        #   [1]: attention masks
        #   [2]: labels

        b_input_ids = batch[0].to(device)
        b_input_mask = batch[1].to(device)
        # b_poincare = batch[2].to(device)
        # b_difficulty = batch[3].to(device)
        b_labels = batch[2].to(device)
        # skill_labels = batch[3].to(device)

        # Always clear any previously calculated gradients before performing a
        # backward pass. PyTorch doesn't do this automatically because
        # accumulating the gradients is "convenient while training RNNs".
        # (source: https://stackoverflow.com/questions/48001598/why-do-we-need-to-call-zero-grad-in-pytorch)
        model.zero_grad()

        # Perform a forward pass (evaluate the model on this training batch).
        probas = model(b_input_ids,b_input_mask)

        # Accumulate the training loss over all of the batches so that we can
        # calculate the average loss at the end. `loss` is a Tensor containing a
        # single value; the `.item()` function just returns the Python value
        # from the tensor.
        loss = loss_func(probas, b_labels)
        total_train_loss += loss.item()

        # Perform a backward pass to calculate the gradients.
        loss.backward()

        # Clip the norm of the gradients to 1.0.
        # This is to help prevent the "exploding gradients" problem.
        # torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)

        # Update parameters and take a step using the computed gradient.
        # The optimizer dictates the "update rule"--how the parameters are
        # modified based on their gradients, the learning rate, etc.
        optimizer.step()

        # Update the learning rate.
        # scheduler.step()
        logits = probas.detach().cpu().numpy()
        label_ids = b_labels.to('cpu').numpy()
        total_train_accuracy += flat_accuracy(logits, label_ids)
    avg_train_accuracy = total_train_accuracy / len(train_dataloader)
    print(" Train Accuracy: {0:.2f}".format(avg_train_accuracy))

    # Calculate the average loss over all of the batches.
    avg_train_loss = total_train_loss / len(train_dataloader)



    # Measure how long this epoch took.
    training_time = format_time(time.time() - t0)

    print("")
    print("  Average training loss: {0:.2f}".format(avg_train_loss))
    print("  Training epcoh took: {:}".format(training_time))

    # ========================================
    #               Validation
    # ========================================
    # After the completion of each training epoch, measure our performance on
    # our validation set.

    print("")
    print("Running Validation...")

    t0 = time.time()

    # Put the model in evaluation mode--the dropout layers behave differently
    # during evaluation.
    model.eval()

    # Tracking variables
    total_eval_accuracy = 0
    total_eval_loss = 0
    nb_eval_steps = 0

    # Evaluate data for one epoch
    for batch in validation_dataloader:

        # Unpack this training batch from our dataloader.
        #
        # As we unpack the batch, we'll also copy each tensor to the GPU using
        # the `to` method.
        #
        # `batch` contains three pytorch tensors:
        #   [0]: input ids
        #   [1]: attention masks
        #   [2]: labels
        b_input_ids = batch[0].to(device)

        b_input_mask = batch[1].to(device)
        # b_poincare = batch[2].to(device)
        # b_difficulty = batch[3].to(device)
        b_labels = batch[2].to(device)
        # skill_labels = batch[3].to(device)

        # Tell pytorch not to bother with constructing the compute graph during
        # the forward pass, since this is only needed for backprop (training).
        with torch.no_grad():

            # Forward pass, calculate logit predictions.

          logits = model(b_input_ids,b_input_mask)

        # Accumulate the validation loss.
        loss = loss_func(logits, b_labels)
        total_eval_loss += loss.item()

        # Move logits and labels to CPU
        logits = logits.detach().cpu().numpy()
        label_ids = b_labels.to('cpu').numpy()

        # Calculate the accuracy for this batch of test sentences, and
        # accumulate it over all batches.
        total_eval_accuracy += flat_accuracy(logits, label_ids)


    # Report the final accuracy for this validation run.
    avg_val_accuracy = total_eval_accuracy / len(validation_dataloader)
    print("  Accuracy: {0:.2f}".format(avg_val_accuracy))

    # Calculate the average loss over all of the batches.
    avg_val_loss = total_eval_loss / len(validation_dataloader)
    early_stopping(avg_val_loss, model)
    if early_stopping.early_stop:
      print("Early stopping")
      break
    # Measure how long the validation run took.
    validation_time = format_time(time.time() - t0)

    print("  Validation Loss: {0:.2f}".format(avg_val_loss))
    print("  Validation took: {:}".format(validation_time))
    output_dir = f'/content/drive/MyDrive/TUDelft/NLP Group Project/deberta-outputs'
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    print("Saving model to %s" % output_dir)
    tokenizer.save_pretrained(output_dir)
    torch.save(model.state_dict(), os.path.join(output_dir, 'model_weights'))

    # Record all statistics from this epoch.
    training_stats.append(
        {
            'epoch': epoch_i + 1,
            'Training Loss': avg_train_loss,
            'Valid. Loss': avg_val_loss,
            'Valid. Accur.': avg_val_accuracy,
            'Training Time': training_time,
            'Validation Time': validation_time
        }
    )

print("")
print("Training complete!")

print("Total training took {:} (h:mm:ss)".format(format_time(time.time()-total_t0)))
# Out:
# ======== Epoch 1 / 20 ========
# Training...
#   Batch    40  of    621.    Elapsed: 0:00:36.
#   Batch    80  of    621.    Elapsed: 0:01:12.
#   Batch   120  of    621.    Elapsed: 0:01:48.
#   Batch   160  of    621.    Elapsed: 0:02:24.
#   Batch   200  of    621.    Elapsed: 0:03:00.
#   Batch   240  of    621.    Elapsed: 0:03:36.
#   Batch   280  of    621.    Elapsed: 0:04:12.
#   Batch   320  of    621.    Elapsed: 0:04:49.
#   Batch   360  of    621.    Elapsed: 0:05:25.
#   Batch   400  of    621.    Elapsed: 0:06:01.
#   Batch   440  of    621.    Elapsed: 0:06:38.
#   Batch   480  of    621.    Elapsed: 0:07:14.
#   Batch   520  of    621.    Elapsed: 0:07:50.
#   Batch   560  of    621.    Elapsed: 0:08:26.
#   Batch   600  of    621.    Elapsed: 0:09:03.
#  Train Accuracy: 0.62
#
#   Average training loss: 0.85
#   Training epcoh took: 0:09:22
#
# Running Validation...
#   Accuracy: 0.64
# Validation loss decreased (inf --> 0.807717).  Saving model ...
#   Validation Loss: 0.81
#   Validation took: 0:01:15
# Saving model to /content/drive/MyDrive/TUDelft/NLP Group Project/deberta-outputs
#
# ======== Epoch 2 / 20 ========
# Training...
#   Batch    40  of    621.    Elapsed: 0:00:37.
#   Batch    80  of    621.    Elapsed: 0:01:14.
#   Batch   120  of    621.    Elapsed: 0:01:50.
#   Batch   160  of    621.    Elapsed: 0:02:26.
#   Batch   200  of    621.    Elapsed: 0:03:02.
#   Batch   240  of    621.    Elapsed: 0:03:38.
#   Batch   280  of    621.    Elapsed: 0:04:15.
#   Batch   320  of    621.    Elapsed: 0:04:51.
#   Batch   360  of    621.    Elapsed: 0:05:27.
#   Batch   400  of    621.    Elapsed: 0:06:03.
#   Batch   440  of    621.    Elapsed: 0:06:40.
#   Batch   480  of    621.    Elapsed: 0:07:16.
#   Batch   520  of    621.    Elapsed: 0:07:52.
#   Batch   560  of    621.    Elapsed: 0:08:28.
#   Batch   600  of    621.    Elapsed: 0:09:05.
#  Train Accuracy: 0.67
#
#   Average training loss: 0.74
#   Training epcoh took: 0:09:23
#
# Running Validation...
#   Accuracy: 0.64
# EarlyStopping counter: 1 out of 2
#   Validation Loss: 0.82
#   Validation took: 0:01:03
# Saving model to /content/drive/MyDrive/TUDelft/NLP Group Project/deberta-outputs
#
# ======== Epoch 3 / 20 ========
# Training...
#   Batch    40  of    621.    Elapsed: 0:00:37.
#   Batch    80  of    621.    Elapsed: 0:01:13.
#   Batch   120  of    621.    Elapsed: 0:01:49.
#   Batch   160  of    621.    Elapsed: 0:02:26.
#   Batch   200  of    621.    Elapsed: 0:03:02.
#   Batch   240  of    621.    Elapsed: 0:03:38.
#   Batch   280  of    621.    Elapsed: 0:04:14.
#   Batch   320  of    621.    Elapsed: 0:04:50.
#   Batch   360  of    621.    Elapsed: 0:05:27.
#   Batch   400  of    621.    Elapsed: 0:06:03.
#   Batch   440  of    621.    Elapsed: 0:06:39.
#   Batch   480  of    621.    Elapsed: 0:07:15.
#   Batch   520  of    621.    Elapsed: 0:07:51.
#   Batch   560  of    621.    Elapsed: 0:08:28.
#   Batch   600  of    621.    Elapsed: 0:09:04.
#  Train Accuracy: 0.73
#
#   Average training loss: 0.63
#   Training epcoh took: 0:09:23
#
# Running Validation...
#   Accuracy: 0.66
# Validation loss decreased (0.807717 --> 0.798172).  Saving model ...
#   Validation Loss: 0.80
#   Validation took: 0:01:05
# Saving model to /content/drive/MyDrive/TUDelft/NLP Group Project/deberta-outputs
#
# ======== Epoch 4 / 20 ========
# Training...
#   Batch    40  of    621.    Elapsed: 0:00:37.
#   Batch    80  of    621.    Elapsed: 0:01:13.
#   Batch   120  of    621.    Elapsed: 0:01:49.
#   Batch   160  of    621.    Elapsed: 0:02:26.
#   Batch   200  of    621.    Elapsed: 0:03:02.
#   Batch   240  of    621.    Elapsed: 0:03:38.
#   Batch   280  of    621.    Elapsed: 0:04:15.
#   Batch   320  of    621.    Elapsed: 0:04:51.
#   Batch   360  of    621.    Elapsed: 0:05:27.
#   Batch   400  of    621.    Elapsed: 0:06:03.
#   Batch   440  of    621.    Elapsed: 0:06:39.
#   Batch   480  of    621.    Elapsed: 0:07:16.
#   Batch   520  of    621.    Elapsed: 0:07:52.
#   Batch   560  of    621.    Elapsed: 0:08:28.
#   Batch   600  of    621.    Elapsed: 0:09:04.
#  Train Accuracy: 0.79
#
#   Average training loss: 0.50
#   Training epcoh took: 0:09:23
#
# Running Validation...
#   Accuracy: 0.63
# EarlyStopping counter: 1 out of 2
#   Validation Loss: 0.89
#   Validation took: 0:01:03
# Saving model to /content/drive/MyDrive/TUDelft/NLP Group Project/deberta-outputs
#
# ======== Epoch 5 / 20 ========
# Training...
#   Batch    40  of    621.    Elapsed: 0:00:37.
#   Batch    80  of    621.    Elapsed: 0:01:13.
#   Batch   120  of    621.    Elapsed: 0:01:49.
#   Batch   160  of    621.    Elapsed: 0:02:26.
#   Batch   200  of    621.    Elapsed: 0:03:02.
#   Batch   240  of    621.    Elapsed: 0:03:38.
#   Batch   280  of    621.    Elapsed: 0:04:14.
#   Batch   320  of    621.    Elapsed: 0:04:50.
#   Batch   360  of    621.    Elapsed: 0:05:27.
#   Batch   400  of    621.    Elapsed: 0:06:03.
#   Batch   440  of    621.    Elapsed: 0:06:39.
#   Batch   480  of    621.    Elapsed: 0:07:16.
#   Batch   520  of    621.    Elapsed: 0:07:52.
#   Batch   560  of    621.    Elapsed: 0:08:28.
#   Batch   600  of    621.    Elapsed: 0:09:05.
#  Train Accuracy: 0.86
#
#   Average training loss: 0.35
#   Training epcoh took: 0:09:24
#
# Running Validation...
#   Accuracy: 0.62
# EarlyStopping counter: 2 out of 2
# Early stopping
#
# Training complete!
# Total training took 0:52:50 (h:mm:ss)

# %% [markdown]
# ## Loading the model

# %% [markdown]
# If you have already trained the model, you can load the model with the weights, and directly use it for inference

# %%
import json
with open("/content/drive/MyDrive/TUDelft/NLP Group Project/data/val_claims_quantemp.json") as f:
  val_data = json.load(f)
len(val_data)
# Out:
# 3084

# %%
tokenizer = AutoTokenizer.from_pretrained('/content/drive/MyDrive/ecir_compnumfacts/tokenizer')
# Out:
# ---------------------------------------------------------------------------
# HFValidationError                         Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/transformers/utils/hub.py in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     398         # Load from URL or cache if already cached
# --> 399         resolved_file = hf_hub_download(
#     400             path_or_repo_id,
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#     105             if arg_name in ["repo_id", "from_id", "to_id"]:
# --> 106                 validate_repo_id(arg_value)
#     107
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_validators.py in validate_repo_id(repo_id)
#     153     if repo_id.count("/") > 1:
# --> 154         raise HFValidationError(
#     155             "Repo id must be in the form 'repo_name' or 'namespace/repo_name':"
#
# HFValidationError: Repo id must be in the form 'repo_name' or 'namespace/repo_name': '/content/drive/MyDrive/ecir_compnumfacts/tokenizer'. Use `repo_type` argument if needed.
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-27-f173feb5ba4d> in <cell line: 1>()
# ----> 1 tokenizer = AutoTokenizer.from_pretrained('/content/drive/MyDrive/ecir_compnumfacts/tokenizer')
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/tokenization_auto.py in from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#     815
#     816         # Next, let's try to use the tokenizer_config file to get the tokenizer class.
# --> 817         tokenizer_config = get_tokenizer_config(pretrained_model_name_or_path, **kwargs)
#     818         if "_commit_hash" in tokenizer_config:
#     819             kwargs["_commit_hash"] = tokenizer_config["_commit_hash"]
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/tokenization_auto.py in get_tokenizer_config(pretrained_model_name_or_path, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, **kwargs)
#     647
#     648     commit_hash = kwargs.get("_commit_hash", None)
# --> 649     resolved_config_file = cached_file(
#     650         pretrained_model_name_or_path,
#     651         TOKENIZER_CONFIG_FILE,
#
# /usr/local/lib/python3.10/dist-packages/transformers/utils/hub.py in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     461         raise EnvironmentError(f"There was a specific connection error when trying to load {path_or_repo_id}:\n{err}")
#     462     except HFValidationError as e:
# --> 463         raise EnvironmentError(
#     464             f"Incorrect path_or_model_id: '{path_or_repo_id}'. Please provide either the path to a local folder or the repo_id of a model on the Hub."
#     465         ) from e
#
# OSError: Incorrect path_or_model_id: '/content/drive/MyDrive/ecir_compnumfacts/tokenizer'. Please provide either the path to a local folder or the repo_id of a model on the Hub.

# %%
model.load_state_dict(torch.load("/content/drive/MyDrive/ecir_compnumfacts/model_roberta_large_oracle/model_weights"))
model.eval()

# %%
loss_func = nn.CrossEntropyLoss()
softmax = nn.Softmax(dim=1)

correct = []
incorrect = []


for batch in validation_dataloader:


    b_input_ids = batch[0].to(device)
    b_input_mask = batch[1].to(device)
    b_labels = batch[2].to(device)

    with torch.no_grad():

      logits = model(b_input_ids,b_input_mask)
      predicted_labels = torch.argmax(softmax(logits), dim=1)

      # Now, predicted labels is one hot encoded.
      for i in range(len(b_labels)):
        if (predicted_labels[i] != b_labels[i]):
          incorrect.append(tokenizer.decode(b_input_ids[i]))
        else:
          correct.append(tokenizer.decode(b_input_ids[i]))

# %%
# Printing some correctly classified documents
correct[0]

# %%
incorrect[23]

# %%
correct_dump = json.dumps(correct, indent=4)

with open('deberta_v3_correct.json', 'w') as json_file:
    json_file.write(correct_dump)

# %%
incorrect_dump = json.dumps(incorrect, indent=4)

with open('deberta_v3_incorrect.json', 'w') as json_file:
    json_file.write(incorrect_dump)

# %% [markdown]
# # Testing

# %% [markdown]
# ## Run Test set

# %%
from torch.utils.data import DataLoader, RandomSampler

test_dataset = torch.load('/content/drive/MyDrive/TUDelft/NLP Group Project/bm25/test_dataset_tokenized_by_deberta.pt')
test_dataloader = DataLoader(
            test_dataset,
            sampler = RandomSampler(test_dataset), # Select batches randomly
            batch_size = batch_size
        )

# %%
import torch
import json
from transformers import AutoTokenizer
from torch.utils.data import DataLoader, TensorDataset
from tqdm import tqdm
import numpy as np
from sklearn.metrics import accuracy_score, f1_score, classification_report, precision_recall_fscore_support
from collections import defaultdict, Counter

NAME_OF_MODEL = 'deberta'

model = MultiClassClassifier('sileod/deberta-v3-base-tasksource-nli', labels_count=3, hidden_dim=1024, mlp_dim=768, extras_dim=140, dropout=0.1, freeze_bert=False)
model.load_state_dict(torch.load(f'/content/drive/MyDrive/TUDelft/NLP Group Project/{NAME_OF_MODEL}-outputs/model_weights'))

if torch.cuda.is_available():
    model.cuda()
    print("Model moved to GPU.")
else:
    print("GPU not available, using CPU.")

model.eval()

batch_size = 16

# label_mapping = list(le.classes_)
label_mapping = ['Conflicting', 'False', 'True']
print(label_mapping)

test_taxonomy_labels = [fact["taxonomy_label"] for fact in test_data]
print("test_taxonomy_labels", test_taxonomy_labels)

loss_func = nn.CrossEntropyLoss()
softmax = nn.Softmax(dim=1)

correct = []
incorrect = []
taxonomy_metrics = defaultdict(lambda: defaultdict(list))
overall_true_labels = []
overall_predictions = []

for i, batch in enumerate(tqdm(test_dataloader, desc="Evaluating")):
    batch = tuple(t.cuda() if torch.cuda.is_available() else t for t in batch)
    b_input_ids, b_input_mask, b_labels = batch

    with torch.no_grad():
        logits = model(b_input_ids, b_input_mask)
        predicted_labels = torch.argmax(softmax(logits), dim=1)
          # Now, predicted labels is one hot encoded.
        start_index = i * batch_size
        for j in range(len(b_labels)):
          decoded_sentence = tokenizer.decode(b_input_ids[j], skip_special_tokens=True)
          true_label = label_mapping[b_labels[j].item()]
          predicted_label = label_mapping[predicted_labels[j].item()]
          taxonomy = test_taxonomy_labels[start_index + j]
          result_info = {
            "Tokenizer_decoded": decoded_sentence,
            "Ground_truth": true_label,
            "Predicted_as": predicted_label,
            "Taxonomy": taxonomy
          }
          if (predicted_labels[j] != b_labels[j]):
            incorrect.append(result_info)
          else:
            correct.append(result_info)
    # Store overall predictions and true labels for overall metrics
    overall_predictions.extend(predicted_labels.cpu().numpy())
    overall_true_labels.extend(b_labels.cpu().numpy())

    # Store predictions for each taxonomy
    start_index = i * batch_size
    for j in range(len(b_labels)):
        taxonomy = test_taxonomy_labels[start_index + j]
        taxonomy_metrics[taxonomy]['true'].append(b_labels[j].item())
        taxonomy_metrics[taxonomy]['pred'].append(predicted_labels[j].item())

# Calculate overall metrics
overall_macro_f1 = f1_score(overall_true_labels, overall_predictions, average='macro', zero_division=0)
overall_weighted_f1 = f1_score(overall_true_labels, overall_predictions, average='weighted', zero_division=0)
_, _, overall_f1_per_class, _ = precision_recall_fscore_support(overall_true_labels, overall_predictions, average=None)

# Prepare to collect taxonomy-specific metrics
taxonomy_specific_metrics = {}
for taxonomy, data in taxonomy_metrics.items():
    macro_f1 = f1_score(data['true'], data['pred'], average='macro')
    weighted_f1 = f1_score(data['true'], data['pred'], average='weighted')
    _, _, f1_per_class, _ = precision_recall_fscore_support(data['true'], data['pred'], average=None)
    taxonomy_specific_metrics[taxonomy] = {
        'macro_f1': macro_f1,
        'weighted_f1': weighted_f1,
        'per_class_f1': f1_per_class
    }

latex_row = "Awesome-Model"
for taxonomy in ["statistical", "temporal", "interval", "comparison"]:
    if taxonomy in taxonomy_specific_metrics:
        latex_row += f" & {taxonomy_specific_metrics[taxonomy]['macro_f1']:.2f} & {taxonomy_specific_metrics[taxonomy]['weighted_f1']:.2f}"
    else:
        latex_row += " & - & -"

# Add per-class F1 scores
latex_row += f" & {overall_f1_per_class[2]:.2f} & {overall_f1_per_class[1]:.2f} & {overall_f1_per_class[0]:.2f}"

# Add overall QUANTemp scores
latex_row += f" & {overall_macro_f1:.2f} & {overall_weighted_f1:.2f} \\\\"

print("\nLatex row:    & M-F1 & W-F1 & M-F1 & W-F1 & M-F1 & W-F1 & M-F1 & W-F1 & T-F1 & F-F1 & C-F1 & M-F1 & W-F1 ")
print(latex_row)
# Out:
# Model moved to GPU.
# ['Conflicting', 'False', 'True']
# test_taxonomy_labels ['statistical', 'statistical', 'temporal', 'statistical', 'temporal', 'statistical', 'statistical', 'temporal', 'temporal', 'temporal', 'statistical', 'statistical', 'statistical', 'statistical', 'statistical', 'temporal', 'temporal', 'statistical', 'temporal', 'comparison', 'statistical', 'statistical', 'statistical', 'statistical', 'temporal', 'statistical', 'statistical', 'statistical', 'comparison', 'temporal', 'interval', 'temporal', 'statistical', 'temporal', 'statistical', 'interval', 'temporal', 'statistical', 'statistical', 'statistical', 'statistical', 'temporal', 'interval', 'statistical', 'temporal', 'statistical', 'statistical', 'temporal', 'statistical', 'temporal', 'temporal', 'statistical', 'temporal', 'interval', 'comparison', 'interval', 'statistical', 'temporal', 'statistical', 'statistical', 'statistical', 'temporal', 'temporal', 'temporal', 'statistical', 'temporal', 'statistical', 'statistical', 'temporal', 'comparison', 'statistical', 'temporal', 'temporal', 'statistical', 'statistical', 'temporal', 'statistical', 'statistical', 'temporal', 'statistical', 'statistical', 'temporal', 'statistical', 'temporal', 'temporal', 'statistical', 'statistical', 'temporal', 'interval', 'statistical', 'interval', 'statistical', 'comparison', 'statistical', 'statistical', 'temporal', 'interval', 'comparison', 'statistical', 'statistical', 'interval', 'interval', 'statistical', 'interval', 'statistical', 'statistical', 'interval', 'comparison', 'interval', 'temporal', 'statistical', 'statistical', 'temporal', 'statistical', 'statistical', 'comparison', 'temporal', 'statistical', 'comparison', 'statistical', 'comparison', 'statistical', 'statistical', 'statistical', 'statistical', 'statistical', 'interval', 'statistical', 'temporal', 'temporal', 'temporal', 'temporal', 'statistical', 'statistical', 'statistical', 'interval', 'temporal', 'statistical', 'interval', 'comparison', 'comparison', 'statistical', 'statistical', 'statistical', 'temporal', 'statistical', 'comparison', 'statistical', 'comparison', 'statistical', 'temporal', 'statistical', 'statistical', 'temporal', 'statistical', 'statistical', 'statistical', 'statistical', 'statistical', 'temporal', 'statistical', 'statistical', 'temporal', 'temporal', 'temporal', 'comparison', 'temporal', 'statistical', 'statistical', 'temporal', 'comparison', 'statistical', 'temporal', 'temporal', 'comparison', 'statistical', 'interval', 'statistical', 'statistical', 'temporal', 'temporal', 'statistical', 'comparison', 'statistical', 'temporal', 'interval', 'temporal', 'statistical', 'temporal', 'statistical', 'temporal', 'statistical', 'statistical', 'temporal', 'temporal', 'statistical', 'statistical', 'interval', 'temporal', 'statistical', 'temporal', 'interval', 'interval', 'statistical', 'interval', 'comparison', 'statistical', 'temporal', 'statistical', 'temporal', 'temporal', 'temporal', 'statistical', 'statistical', 'statistical', 'interval', 'interval', 'statistical', 'statistical', 'interval', 'temporal', 'statistical', 'statistical', 'statistical', 'temporal', 'statistical', 'interval', 'temporal', 'statistical', 'temporal', 'temporal', 'temporal', 'statistical', 'statistical', 'temporal', 'interval', 'statistical', 'interval', 'statistical', 'temporal', 'temporal', 'temporal', 'statistical', 'temporal', 'statistical', 'interval', 'statistical', 'comparison', 'statistical', 'statistical', 'temporal', 'statistical', 'comparison', 'temporal', 'statistical', 'statistical', 'temporal', 'statistical', 'temporal', 'statistical', 'statistical', 'interval', 'interval', 'temporal', 'statistical', 'interval', 'interval', 'interval', 'statistical', 'temporal', 'statistical', 'statistical', 'statistical', 'interval', 'statistical', 'statistical', 'interval', 'statistical', 'temporal', 'statistical', 'temporal', 'comparison', 'statistical', 'temporal', 'interval', 'comparison', 'statistical', 'temporal', 'statistical', 'interval', 'statistical', 'statistical', ...
# Evaluating: 100%|██████████| 156/156 [00:56<00:00,  2.76it/s]
# Latex row:    & M-F1 & W-F1 & M-F1 & W-F1 & M-F1 & W-F1 & M-F1 & W-F1 & T-F1 & F-F1 & C-F1 & M-F1 & W-F1
# Awesome-Model & 0.53 & 0.61 & 0.56 & 0.62 & 0.56 & 0.63 & 0.52 & 0.61 & 0.52 & 0.76 & 0.34 & 0.54 & 0.61 \\
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print(label_mapping)
# Out:
# ['Conflicting', 'False', 'True']

# %% [markdown]
# ## Save incorrectly classified for qualitative analysis

# %%
correct_dump = json.dumps(correct, indent=4)

with open(f'/content/drive/MyDrive/TUDelft/NLP Group Project/{NAME_OF_MODEL}-outputs/test_results/{NAME_OF_MODEL}_correctly_classified_test_items.json', 'w') as json_file:
    json_file.write(correct_dump)

incorrect_dump = json.dumps(incorrect, indent=4)

with open(f'/content/drive/MyDrive/TUDelft/NLP Group Project/{NAME_OF_MODEL}-outputs/test_results/{NAME_OF_MODEL}_incorrectly_classified_test_items.json', 'w') as json_file:
    json_file.write(incorrect_dump)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-29-4cc9a0502aba> in <cell line: 8>()
#       6 incorrect_dump = json.dumps(incorrect, indent=4)
#       7
# ----> 8 with open(f'/content/drive/MyDrive/TUDelft/NLP Group Project/{NAME_OF_MODEL}-outputs/test_results/{NAME_OF_MODEL}_incorrectly_classified_test_items.json', 'w') as json_file:
#       9     json_file.write(incorrect_dump)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/TUDelft/NLP Group Project/deberta-outputs/test_results/deberta_incorrectly_classified_test_items.json'

# %% [markdown]
# ## Confusion Matrices

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
import numpy as np

def plot_confusion_matrix(cm, class_names, title):
    """
    Returns a matplotlib figure containing the plotted confusion matrix.

    Args:
    cm (array, shape = [n, n]): a confusion matrix of integer classes
    class_names (array, shape = [n]): String names of the integer classes
    title (str): Title of the heatmap.
    """
    # Normalize the confusion matrix.
    cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    fig, ax = plt.subplots(figsize=(6,6))  # Adjust to fit your needs
    sns.heatmap(cm_normalized, annot=True, fmt=".2f", cmap='Blues', cbar=False, ax=ax,
                xticklabels=class_names, yticklabels=class_names)

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.title(title)
    plt.show()
    plt.close()  # Close the plot to avoid direct output
    return fig

# Calculate confusion matrices and plot them
categories = ['statistical', 'temporal', 'interval', 'comparison', 'overall']
class_labels = ['Conflicting', 'False', 'True']

# Generate and save confusion matrix plots
for category in categories:
    true_labels = taxonomy_metrics[category]['true'] if category != 'overall' else overall_true_labels
    pred_labels = taxonomy_metrics[category]['pred'] if category != 'overall' else overall_predictions
    cm = confusion_matrix(true_labels, pred_labels, labels=[0, 1, 2])

    fig = plot_confusion_matrix(cm, class_labels, f'{NAME_OF_MODEL.upper()} {category.upper()}')
    fig.savefig(f'/content/drive/MyDrive/TUDelft/NLP Group Project/{NAME_OF_MODEL}-outputs/confusion_matrices/{NAME_OF_MODEL}_{category}_confusion_matrix.png')  # Save the figure

# %%
from collections import Counter

# Assuming overall_true_labels and overall_predictions are populated
true_label_counts = Counter(overall_true_labels)
predicted_label_counts = Counter(overall_predictions)

# If using LabelEncoder to transform labels, ensure it's fitted as shown previously
label_mapping = list(LE.classes_)  # E.g., ['Conflicting', 'False', 'True']

# Print counts for true labels
print("Counts of each class in the test set:")
for label_index, count in true_label_counts.items():
    print(f"{label_mapping[label_index]}: {count}")

# Print counts for predicted labels
print("\nCounts of each class predicted by the model:")
for label_index, count in predicted_label_counts.items():
    print(f"{label_mapping[label_index]}: {count}")
